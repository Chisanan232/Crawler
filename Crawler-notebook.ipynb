# %%
from bs4 import BeautifulSoup
import requests
import random
import time
import csv

# %% [markdown]
# ## Setting headers to hide the identity that we are crawler program, it can avoid block by web server.

# %%
def get_header():
    user_agent = [
        'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.71 Safari/537.36',
        'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.64 Safari/537.11',
        'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; en) Opera 9.50',
        'Opera/8.0 (Windows NT 5.1; U; en)'
    ]
    headers = {'User-Agent':random.choice(user_agent)}
    return headers

# %%
weatherfile = r'C:\Users\iAirJordan\Desktop\jupyter-data\weather-1.csv'
#The path where save data you crawled

# %%
# Our data's headers
fields = ['Time', 'Weather', 'Temperature', 'Wind', 'Barometer', 'Wind Direction', 'Humidity', 'Visibility']

f = open(weatherfile, 'a+', newline='', encoding='utf-8')
file = csv.writer(f)
file.writerow(fields)
# Out:
# 76

# %%
for year in range(2013, 2014):
    for month in range(1, 3):
        urlhead = 'https://www.timeanddate.com/weather/usa/new-york/historic?month='
        urlmid = '&year='
        url = urlhead + str(month) + urlmid + str(year)

        print(url)

        # Download content of the web and get the source code of the web
        html = requests.get(url, headers=get_header())

        # Make sure we download success or not
        if html.status_code == requests.codes.ok:

            # Parse HTML code with BeautifulSoup
            soup = BeautifulSoup(html.text, 'html.parser')

            # Get the data we want by CSS syntax
            tableRow = soup.select('#wt-his > tbody > tr')
            #print(tableRow)

            for row in tableRow:

                Time = row.select_one('th').text
                #time = row.select('th')[0].text

                #    print('Time : ', Time)
                #hit = th[0].text
                # print(Time)

                weather = row.select('.mtt')[0].get('title')
                # print('Weather : ', weather)

                Temp = row.select_one('.wt-ic + td').text
                # print('Temperature : ', Temp)

                wind = row.select('.sep')[0].text
                # print('Wind : ', wind)
                Barometer = row.select('.sep')[1].text
                # print('Barometer : ', Barometer)

                wind_dir = row.select('.comp')[0].get('title')
                #    print('Wind Direction : ', wind_dir)

                Bar = row.select('.sep')[1]
                Humidity = Bar.find_previous_siblings('td')[0].text
                # print('Humidity : ', Humidity)

                Bar = row.select('.sep')[1]
                Visibility = Bar.find_next_siblings('td')[0].text
                # print('Visibility : ', Visibility)

                # print('========================================')

                # We may get some impurity we don't need in data, so we have to remove it.
#                 Temp1 = "".join(Temp.split())
#                 Visibility1 = "".join(Visibility.split())
                # nws = [time, weather, Temp1, wind, Barometer, wind_dir, Humidity, Visibility1]
                # print(nws)

                file.writerow([Time, weather, Temp, wind, Barometer, wind_dir, Humidity, Visibility])

        # Feign we are human to browse the web to avoid be blocked by web server, and in other hand, decrease stress on
        # server, we are good crawler program.
        time.sleep(random.randint(3, 12))

# Remember close the file you opened, release your memory space, it's easily to forget.
f.close()

print('finish')
# Out:
# https://www.timeanddate.com/weather/usa/new-york/historic?month=1&year=2013
# https://www.timeanddate.com/weather/usa/new-york/historic?month=2&year=2013
# finish

# %%
import pandas as pd

# %%
weather_1_df = pd.DataFrame(pd.read_csv(weatherfile))
weather_1_df
# Out:
#                Time            Weather Temperature     Wind  Barometer  \
# 0   00:51Tue, 1 Jan          Overcast.        4 °C  17 km/h  1011 mbar
# 1             01:51          Overcast.        3 °C   6 km/h  1012 mbar
# 2             02:51          Overcast.        4 °C  11 km/h  1012 mbar
# 3             03:51          Overcast.        4 °C  15 km/h  1012 mbar
# 4             04:51          Overcast.        4 °C  11 km/h  1012 mbar
# 5             05:51          Overcast.        4 °C  11 km/h  1011 mbar
# 6             06:51          Overcast.        4 °C  17 km/h  1012 mbar
# 7             07:51          Overcast.        3 °C  11 km/h  1012 mbar
# 8             08:51     Mostly cloudy.        4 °C  11 km/h  1012 mbar
# 9             09:51    Passing clouds.        4 °C  17 km/h  1012 mbar
# 10            10:51          Overcast.        4 °C   9 km/h  1012 mbar
# 11            11:51          Overcast.        4 °C   7 km/h  1011 mbar
# 12            12:51          Overcast.        3 °C  15 km/h  1011 mbar
# 13            13:51          Overcast.        3 °C  No wind  1010 mbar
# 14            14:51      Partly sunny.        3 °C  11 km/h  1010 mbar
# 15            15:51  Scattered clouds.        3 °C  11 km/h  1012 mbar
# 16            16:51             Clear.        2 °C  17 km/h  1012 mbar
# 17            17:51             Clear.        2 °C   7 km/h  1013 mbar
# 18            18:51             Clear.        1 °C   9 km/h  1014 mbar
# 19            19:51             Clear.        0 °C   7 km/h  1014 mbar
# 20            20:51             Clear.       -1 °C  11 km/h  1015 mbar
# 21            21:51             Clear.       -2 °C  19 km/h  1015 mbar
# 22            22:51             Clear.       -3 °C      NaN  1016 mbar
# 23            23:51             Clear.       -3 °C   9 km/h  1016 mbar
# 24  00:51Fri, 1 Feb             Clear.       -2 °C  20 km/h  1009 mbar
# 25            01:51             Clear.       -2 °C   9 km/h  1009 mbar
# 26            02:51    Passing clouds.       -2 °C  No wind  1009 mbar
# 27            03:51             Clear.       -2 °C   9 km/h  1009 mbar
# 28            04:51             Clear.       -2 °C  13 km/h  1009 mbar
# 29            05:51    Passing clouds.       -2 °C      NaN  1010 mbar
# 30            06:51    Passing clouds.       -2 °C  13 km/h  1010 mbar
# 31            07:51      Partly sunny.       -2 °C  15 km/h  1011 mbar
# 32            08:51     Mostly cloudy.       -2 °C  17 km/h  1011 mbar
# 33            09:51          Overcast.       -2 °C  11 km/h  1012 mbar
# 34            10:51          Overcast.       -2 °C  17 km/h  1012 mbar
# 35            11:51     Broken clouds.       -1 °C  19 km/h  1011 mbar
# 36            12:51      Partly sunny.       -1 °C      NaN  1011 mbar
# 37            13:51      Partly sunny.       -1 °C  24 km/h  1012 mbar
# 38            14:51      Partly sunny.       -2 °C  15 km/h  1014 mbar
# 39            15:51    Passing clouds.       -2 °C      NaN  1015 mbar
# 40            16:51             Sunny.       -2 °C  11 km/h  1016 mbar
# 41            17:51    Passing clouds.       -3 °C  19 km/h  1018 mbar
# 42            18:51    Passing clouds.       -3 °C  11 km/h  1019 mbar
# 43            19:51             Clear.       -3 °C      NaN  1020 mbar
# 44            20:51     Partly cloudy.       -3 °C   7 km/h  1021 mbar
# 45            21:51             Clear.       -4 °C  13 km/h  1022 mbar
# 46            22:51             Clear.       -4 °C  22 km/h  1023 mbar
# 47            23:51             Clear.       -4 °C  15 km/h  1024 mbar
#
#                                        Wind Direction Humidity Visibility
# 0                 Wind blowing from 260° West to East      55%      16 km
# 1                 Wind blowing from 0° North to South      63%      16 km
# 2                 Wind blowing from 0° North to South      62%      16 km
# 3                 Wind blowing from 260° West to East      62%      16 km
# 4                 Wind blowing from 0° North to South      62%      16 km
# 5                 Wind blowing from 0° North to South      60%      16 km
# 6                 Wind blowing from 260° West to East      60%      16 km
# 7                 Wind blowing from 260° West to East      65%      16 km
# 8                 Wind blowing from 0° North to South      62%      16 km
# 9                 Wind blowing from 260° West to East      62%      16 km
# 10                Wind blowing from 0° North to South      62%      16 km
# 11                Wind blowing from 0° North to South      60%      16 km
# 12  Wind blowing from 300° West-northwest to East-...      62%      16 km
# 13                Wind blowing from 0° North to South      62%      16 km
# 14                Wind blowing from 0° North to South      58%      16 km
# 15                Wind blowing from 0° North to South      51%      16 km
# 16      Wind blowing from 310° Northwest to Southeast      48%      16 km
# 17                Wind blowing from 0° North to South      46%      16 km
# 18      Wind blowing from 310° Northwest to Southeast      48%      16 km
# 19                Wind blowing from 0° North to South      47%      16 km
# 20                Wind blowing from 0° North to South      49%      16 km
# 21      Wind blowing from 310° Northwest to Southeast      49%      16 km
# 22             Wind blowing from -128° North to South      46%      16 km
# 23  Wind blowing from 300° West-northwest to East-...      50%      16 km
# 24  Wind blowing from 250° West-southwest to East-...      45%      16 km
# 25                Wind blowing from 0° North to South      47%      16 km
# 26                Wind blowing from 0° North to South      47%      16 km
# 27                Wind blowing from 0° North to South      49%      16 km
# 28  Wind blowing from 250° West-southwest to East-...      45%      16 km
# 29             Wind blowing from -128° North to South      51%      16 km
# 30                Wind blowing from 280° West to East      47%      16 km
# 31  Wind blowing from 300° West-northwest to East-...      47%      16 km
# 32                Wind blowing from 280° West to East      47%      16 km
# 33  Wind blowing from 290° West-northwest to East-...      41%      16 km
# 34      Wind blowing from 310° Northwest to Southeast      39%      16 km
# 35  Wind blowing from 300° West-northwest to East-...      33%      16 km
# 36             Wind blowing from -128° North to South      33%      16 km
# 37  Wind blowing from 290° West-northwest to East-...      34%      16 km
# 38      Wind blowing from 310° Northwest to Southeast      39%      16 km
# 39             Wind blowing from -128° North to South      36%      16 km
# 40  Wind blowing from 290° West-northwest to East-...      41%      16 km
# 41  Wind blowing from 300° West-northwest to East-...      53%      16 km
# 42                Wind blowing from 0° North to South      55%      16 km
# 43             Wind blowing from -128° North to South      52%      16 km
# 44                Wind blowing from 0° North to South      50%      16 km
# 45                Wind blowing from 280° West to East      60%      16 km
# 46  Wind blowing from 290° West-northwest to East-...      57%      16 km
# 47                Wind blowing from 280° West to East      52%      16 km

# %% [markdown]
# ## If we check our content of csv file, you can discover that our data have trouble in column 'Temperature', the data is '4?簞C', have some impurity in it.

# %% [markdown]
# ## Test a little measure that when your program is running it can print something to show process of your program.

# %%
import sys, time

# %%
for i in range(51):
    sys.stdout.write('\r')
    sys.stdout.write("[%-50s] %d%%" % ('=' * i, 2 * i))
    sys.stdout.flush()
    time.sleep(0.25)
# Out:
# [==================================================] 100%

# %%
for i in range(51):
    sys.stdout.write('\r')
    sys.stdout.write("%-50s [%d%%]" % ('=' * i, 2 * i))
    sys.stdout.flush()
    time.sleep(0.25)
# Out:
# ================================================== [100%]

# %% [markdown]
# More information about application of '%' in syntax of print: <br>
# http://www.cnblogs.com/vamei/archive/2013/03/12/2954938.html

# %%
for i in range(100):
    k = i + 1
    str1 = '>' * (i // 2) + ' ' * ((100 - k) // 2)
    sys.stdout.write('\r' + str1 + '[%s%%]' % (i + 1))
    sys.stdout.flush()
    time.sleep(0.1)
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[100%]

# %%
for i in range(51):
    time.sleep(0.25)
    sys.stdout.write("\r %d%%" % i)
    sys.stdout.flush()
# Out:
#  50%

# %% [markdown]
# ## Now we can use this application in our program to know our pace.

# %%
weatherfile_improve = r'C:\Users\iAirJordan\Desktop\jupyter-data\weather-1-improve.csv'

f_improve = open(weatherfile_improve, 'a+', newline='', encoding='utf-8-sig')
file_improve = csv.writer(f_improve)
file_improve.writerow(fields)
# Out:
# 76

# %% [markdown]
# ## In here, we should to pay attention to the type of encoding. It will influence the value of column "Temperature". If you use "utf-8", you will get some impurity in value, however, you use like "cp950" or "ASCII" or "Big5" you can get clear value, and, including "utf-8-sig".

# %% [markdown]
# * The url below tell you what is BOM: <br>
# https://atedev.wordpress.com/2007/09/19/bom-bom-bom/ <br><br>
# * The url below tell you the different between "utf-8" and "utf-8-sig": <br>
# https://hk.saowen.com/a/9f4bdeb6d8b8ed781515d8f3c3572f73ccbbf8335d9009a2077a0f1836ad1f75

# %%
start_time = time.time()

for year in range(2013, 2014):
    for month in range(1, 13):
        urlhead = 'https://www.timeanddate.com/weather/usa/new-york/historic?month='
        urlmid = '&year='
        url = urlhead + str(month) + urlmid + str(year)
        html = requests.get(url, headers=get_header())
        if html.status_code == requests.codes.ok:
            soup = BeautifulSoup(html.text, 'html.parser')
            tableRow = soup.select('#wt-his > tbody > tr')
            for row in tableRow:
                Time = row.select_one('th').text
                #time = row.select('th')[0].text
                #hit = th[0].text
                weather = row.select('.mtt')[0].get('title')
                Temp = row.select_one('.wt-ic + td').text
                wind = row.select('.sep')[0].text
                Barometer = row.select('.sep')[1].text
                wind_dir = row.select('.comp')[0].get('title')
                Bar = row.select('.sep')[1]
                Humidity = Bar.find_previous_siblings('td')[0].text
                Bar = row.select('.sep')[1]
                Visibility = Bar.find_next_siblings('td')[0].text

                file_improve.writerow([Time, weather, Temp, wind, Barometer, wind_dir, Humidity, Visibility])
                sys.stdout.write("\r [%-12s] %d%%" % ('=>' * month, (100 / 12) * month))

        time.sleep(random.randint(3, 12))

f_improve.close()

end_time = time.time()
print('\nTotal time: ' + str(end_time - start_time) + ' seconds.')
print('finish')
# Out:
#  [=>=>=>=>=>=>=>=>=>=>=>=>] 100%
# Total time: 95.33200073242188 seconds.
# finish

# %%
weather_1_improve_df = pd.DataFrame(pd.read_csv(weatherfile_improve))
weather_1_improve_df
# Out:
#                 Time            Weather Temperature     Wind  Barometer  \
# 0    00:51Tue, 1 Jan          Overcast.        4 °C  17 km/h  1011 mbar
# 1              01:51          Overcast.        3 °C   6 km/h  1012 mbar
# 2              02:51          Overcast.        4 °C  11 km/h  1012 mbar
# 3              03:51          Overcast.        4 °C  15 km/h  1012 mbar
# 4              04:51          Overcast.        4 °C  11 km/h  1012 mbar
# 5              05:51          Overcast.        4 °C  11 km/h  1011 mbar
# 6              06:51          Overcast.        4 °C  17 km/h  1012 mbar
# 7              07:51          Overcast.        3 °C  11 km/h  1012 mbar
# 8              08:51     Mostly cloudy.        4 °C  11 km/h  1012 mbar
# 9              09:51    Passing clouds.        4 °C  17 km/h  1012 mbar
# 10             10:51          Overcast.        4 °C   9 km/h  1012 mbar
# 11             11:51          Overcast.        4 °C   7 km/h  1011 mbar
# 12             12:51          Overcast.        3 °C  15 km/h  1011 mbar
# 13             13:51          Overcast.        3 °C  No wind  1010 mbar
# 14             14:51      Partly sunny.        3 °C  11 km/h  1010 mbar
# 15             15:51  Scattered clouds.        3 °C  11 km/h  1012 mbar
# 16             16:51             Clear.        2 °C  17 km/h  1012 mbar
# 17             17:51             Clear.        2 °C   7 km/h  1013 mbar
# 18             18:51             Clear.        1 °C   9 km/h  1014 mbar
# 19             19:51             Clear.        0 °C   7 km/h  1014 mbar
# 20             20:51             Clear.       -1 °C  11 km/h  1015 mbar
# 21             21:51             Clear.       -2 °C  19 km/h  1015 mbar
# 22             22:51             Clear.       -3 °C      NaN  1016 mbar
# 23             23:51             Clear.       -3 °C   9 km/h  1016 mbar
# 24   00:51Fri, 1 Feb             Clear.       -2 °C  20 km/h  1009 mbar
# 25             01:51             Clear.       -2 °C   9 km/h  1009 mbar
# 26             02:51    Passing clouds.       -2 °C  No wind  1009 mbar
# 27             03:51             Clear.       -2 °C   9 km/h  1009 mbar
# 28             04:51             Clear.       -2 °C  13 km/h  1009 mbar
# 29             05:51    Passing clouds.       -2 °C      NaN  1010 mbar
# ..               ...                ...         ...      ...        ...
# 259            18:51             Clear.       18 °C   9 km/h  1003 mbar
# 260            19:51             Clear.       18 °C      NaN  1004 mbar
# 261            20:51             Clear.       18 °C   7 km/h  1004 mbar
# 262            21:51             Clear.       18 °C   9 km/h  1005 mbar
# 263            22:51             Clear.       17 °C   9 km/h  1006 mbar
# 264            23:51             Clear.       17 °C  No wind  1005 mbar
# 265  00:51Sun, 1 Dec     Mostly cloudy.        4 °C  No wind  1028 mbar
# 266            01:51    Passing clouds.        3 °C   7 km/h  1027 mbar
# 267            02:51     Mostly cloudy.        2 °C   9 km/h  1026 mbar
# 268            03:51     Partly cloudy.        3 °C  No wind  1025 mbar
# 269            04:51     Mostly cloudy.        3 °C  No wind  1024 mbar
# 270            06:00     Partly cloudy.        4 °C  No wind  1025 mbar
# 271            06:51    Passing clouds.        3 °C  No wind  1024 mbar
# 272            07:51             Sunny.        4 °C  No wind  1024 mbar
# 273            08:51             Sunny.        6 °C  No wind  1023 mbar
# 274            09:51      Partly sunny.        7 °C   6 km/h  1023 mbar
# 275            10:51          Overcast.        7 °C  No wind  1022 mbar
# 276            11:51  Scattered clouds.        8 °C   6 km/h  1021 mbar
# 277            12:51          Overcast.        8 °C   9 km/h  1020 mbar
# 278            13:51          Overcast.        8 °C   6 km/h  1019 mbar
# 279            14:51  Scattered clouds.        9 °C  No wind  1018 mbar
# 280            15:51             Sunny.        9 °C  No wind  1018 mbar
# 281            16:51          Overcast.        9 °C  No wind  1018 mbar
# 282            17:51          Overcast.        9 °C   7 km/h  1018 mbar
# 283            18:51          Overcast.        9 °C  No wind  1018 mbar
# 284            19:51          Overcast.        8 °C   6 km/h  1018 mbar
# 285            20:51    Passing clouds.        8 °C   7 km/h  1017 mbar
# 286            21:51             Clear.        8 °C  No wind  1017 mbar
# 287            22:51          Overcast.        8 °C  No wind  1017 mbar
# 288            23:51          Overcast.        7 °C   6 km/h  1016 mbar
#
#                                         Wind Direction Humidity Visibility
# 0                  Wind blowing from 260° West to East      55%      16 km
# 1                  Wind blowing from 0° North to South      63%      16 km
# 2                  Wind blowing from 0° North to South      62%      16 km
# 3                  Wind blowing from 260° West to East      62%      16 km
# 4                  Wind blowing from 0° North to South      62%      16 km
# 5                  Wind blowing from 0° North to South      60%      16 km
# 6                  Wind blowing from 260° West to East      60%      16 km
# 7                  Wind blowing from 260° West to East      65%      16 km
# 8                  Wind blowing from 0° North to South      62%      16 km
# 9                  Wind blowing from 260° West to East      62%      16 km
# 10                 Wind blowing from 0° North to South      62%      16 km
# 11                 Wind blowing from 0° North to South      60%      16 km
# 12   Wind blowing from 300° West-northwest to East-...      62%      16 km
# 13                 Wind blowing from 0° North to South      62%      16 km
# 14                 Wind blowing from 0° North to South      58%      16 km
# 15                 Wind blowing from 0° North to South      51%      16 km
# 16       Wind blowing from 310° Northwest to Southeast      48%      16 km
# 17                 Wind blowing from 0° North to South      46%      16 km
# 18       Wind blowing from 310° Northwest to Southeast      48%      16 km
# 19                 Wind blowing from 0° North to South      47%      16 km
# 20                 Wind blowing from 0° North to South      49%      16 km
# 21       Wind blowing from 310° Northwest to Southeast      49%      16 km
# 22              Wind blowing from -128° North to South      46%      16 km
# 23   Wind blowing from 300° West-northwest to East-...      50%      16 km
# 24   Wind blowing from 250° West-southwest to East-...      45%      16 km
# 25                 Wind blowing from 0° North to South      47%      16 km
# 26                 Wind blowing from 0° North to South      47%      16 km
# 27                 Wind blowing from 0° North to South      49%      16 km
# 28   Wind blowing from 250° West-southwest to East-...      45%      16 km
# 29              Wind blowing from -128° North to South      51%      16 km
# ..                                                 ...      ...        ...
# 259                Wind blowing from 0° North to South      66%       6 km
# 260             Wind blowing from -128° North to South      66%      16 km
# 261                Wind blowing from 0° North to South      66%      16 km
# 262                Wind blowing from 0° North to South      73%      16 km
# 263                Wind blowing from 260° West to East      80%      16 km
# 264                Wind blowing from 0° North to South      83%      16 km
# 265                Wind blowing from 0° North to South      65%      16 km
# 266  Wind blowing from 290° West-northwest to East-...      67%      16 km
# 267  Wind blowing from 300° West-northwest to East-...      67%      16 km
# 268                Wind blowing from 0° North to South      67%      16 km
# 269                Wind blowing from 0° North to South      68%      16 km
# 270                Wind blowing from 0° North to South      67%      16 km
# 271                Wind blowing from 0° North to South      73%      16 km
# 272                Wind blowing from 0° North to South      73%      16 km
# 273                Wind blowing from 0° North to South      68%      16 km
# 274  Wind blowing from 70° East-northeast to West-s...      60%      16 km
# 275                Wind blowing from 0° North to South      60%      16 km
# 276                Wind blowing from 0° North to South      54%      16 km
# 277                Wind blowing from 270° West to East      54%      16 km
# 278                Wind blowing from 0° North to South      48%      16 km
# 279                Wind blowing from 0° North to South      46%      16 km
# 280                Wind blowing from 0° North to South      46%      16 km
# 281                Wind blowing from 0° North to South      46%      16 km
# 282  Wind blowing from 300° West-northwest to East-...      48%      16 km
# 283                Wind blowing from 0° North to South      48%      16 km
# 284                Wind blowing from 280° West to East      48%      16 km
# 285                Wind blowing from 280° West to East      50%      16 km
# 286                Wind blowing from 0° North to South      51%      16 km
# 287                Wind blowing from 0° North to South      50%      16 km
# 288      Wind blowing from 320° Northwest to Southeast      51%      16 km
#
# [289 rows x 8 columns]

# %% [markdown]
# ## Crawler with multithreading

# %%
from tomorrow import threads
import os

# %%
class DefineParameter:
    def __init__(self, save_path, year_initial, year_conclude):
        self.path = save_path
        self.year_initial = year_initial
        self.year_conclude = year_conclude

# %%
class FakeIdentity:
    def get_header(self):
        user_agent = [
            'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.71 Safari/537.36',
            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.64 Safari/537.11',
            'Mozilla/5.0 (Windows NT 5.1; U; en; rv:1.8.1) Gecko/20061208 Firefox/2.0.0 Opera 9.50',
            'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:34.0) Gecko/20100101 Firefox/34.0',
            'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/534.57.2 (KHTML, like Gecko) Version/5.1.7 Safari/534.57.2',
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.79 Safari/537.36 Edge/14.14393'
        ]
        headers = {'User-Agent': random.choice(user_agent)}
        return headers


    def get_proxy(self):
        proxy = ['217.61.125.74:3128',
                 '118.178.93.238:8888',
                 '212.237.15.108:8080',
                 '206.189.220.129:8080',
                 '114.202.2.185:80',
                 '206.189.222.146:8080',
                 '66.119.180.104:80',
                 '187.73.68.14:53281',
                 '194.126.183.141:53281',
                 '95.167.109.76:80',
                 '167.99.235.224:80',
                 '27.255.91.146:80',
                 '47.89.241.103:8080',
                 '47.52.208.159:80',
                 '213.155.250.46:3128',
                 ]
        proxies = {
            'http': 'http://' + random.choice(proxy)
            # Hyper Text Transfer Protocol (HTTP) cannot use carelessly, to remember, HTTP and HTTPS look similar but
            # they are different at all. Here, we have to pay attention to sure your proxy is HTTP or HTTPS. If you want
            # to study more information about http and https, please google.
            # http://blog.51cto.com/laoyinga/2046692
            # 'https':'https://' + random.choice(proxy)
        }
        return proxies

# %%
class AllUrlInWorker(DefineParameter):
    def __init__(self, save_path, year_initial, year_conclude, address):
        super(AllUrlInWorker, self).__init__(save_path=save_path, year_initial=year_initial, year_conclude=year_conclude)
        self.address = address

    '''
    Collect all of urls that we will crawl to get data we want
    '''

    def get_url(self, year_start, year_end, month_start, month_end, day_start, day_end):
        url_address = self.address
        url_head = 'https://www.timeanddate.com/scripts/cityajax.php?n=usa/'
        url_mid = '&mode=historic&hd='
        url_mid_two = '&month='
        url_tail = '&year='

        '''
        A method save urls string we need with for loop.
        First method to get all urls we want to crawl, just use nested for loop. Because we just collect all urls, it's 
        string in list, so we don't consider some problems about efficiency.
        '''
        url_pool = []
        date_list = []

        for year in range(year_start, year_end):
            for month in range(month_start, month_end):
                m = '%02d' % month
                for day in range(day_start, day_end):
                    d = '%02d' % day
                    url = url_head + url_address + url_mid + str(year) + m.zfill(2) + d.zfill(2) + \
                          url_mid_two + str(month) + url_tail + str(year)
                    url_pool.append(url)
                    # date = str(year) + m.zfill(2) + d.zfill(2)
                    date = str(year) + '/' + str(m.zfill(2)) + '/' + str(d.zfill(2))
                    date_list.append(date)
        '''
        Second method save urls string we need with for loop too, but wrote it by 'Python method'.
        It\'s so abnormal, even thought it\'s convenience but it\'s so hard to read and understand what you want to do.
        '''
        # url_pool = [(url_head + url_address + url_mid + str(year) + str(('%02d' % month).zfill(2)) +
        #             str(('%02d' % day).zfill(2)) + url_mid_two + str(month) + url_tail + str(year))
        #             for year in range(year_start, year_end) for month in range(month_start, month_end)
        #             for day in range(day_start, day_end)]
        # date_list = [(str(year) + str(('%02d' % month).zfill(2)) + str(('%02d' % day).zfill(2)))
        #              for year in range(year_start, year_end) for month in range(month_start, month_end)
        #              for day in range(day_start, day_end)]
        return url_pool, date_list

# %%
'''
I try to use 3 methods about 1、120 and 240 threads to crawl data, so I will write three classes to cooperate with different 
number of threads.
'''


class PrepositiveMeasureVerOne(AllUrlInWorker):
    def __init__(self, save_path, year_initial, year_conclude, address):
        super(PrepositiveMeasureVerOne, self).__init__(save_path=save_path, year_initial=year_initial, year_conclude=year_conclude, address=address)

    '''
    This method is applicable to crawl 1 year data
    '''

    def get_job_date(self, name):

        '''
        A method to get url let every worker to do something they should to do
        '''

        # if name == 'worker-no-0':
        #     url_pool, date_list = self.get_url(2013, 2014, 1, 3, 1, 32)
        #     return url_pool, date_list
        # elif name == 'worker-no-1':
        #     url_pool, date_list = self.get_url(2013, 2014, 3, 6, 1, 32)
        #     return url_pool, date_list
        # elif name == 'worker-no-2':
        #     url_pool, date_list = self.get_url(2013, 2014, 5, 7, 1, 32)
        #     return url_pool, date_list
        # elif name == 'worker-no-3':
        #     url_pool, date_list = self.get_url(2013, 2014, 7, 9, 1, 32)
        #     return url_pool, date_list
        # elif name == 'worker-no-4':
        #     url_pool, date_list = self.get_url(2013, 2014, 9, 11, 1, 32)
        #     return url_pool, date_list
        # elif name == 'worker-no-5':
        #     url_pool, date_list = self.get_url(2013, 2014, 11, 13, 1, 32)
        #     return url_pool, date_list
        # else:
        #     print('Not found this worker name.')
        '''
        Second method
        '''
        if name[-3:].isdigit():
            month_begin = 1 + 1 * int(name[-3:])
            month_finish = 2 + 1 * int(name[-3:])
            url_pool, date_list = self.get_url(self.year_initial, self.year_conclude, month_begin, month_finish, 1, 32)
            return url_pool, date_list
        else:
            print('Please check your name of variable \'worker\', the last 3 string is not integer.')
            ans = input('Do you want to stop the program ? (Yes/No)')
            if 'y' in ans or 'Y' in ans:
                sys.exit()
            else:
                print('Program keep operating.')

    def open_file(self, worker):
        file = self.path + str(self.year_initial) + '/weather-' + str(int(int(worker[-3:]) % 12) + 1) + '.csv'
        csv_file = open(file, 'a+', newline='', encoding='utf-8-sig')
        write_file = csv.writer(csv_file)
        return csv_file, write_file

# %%
class PrepositiveMeasureVerTwo(AllUrlInWorker):
    def __init__(self, save_path, year_initial, year_conclude, address):
        super(PrepositiveMeasureVerTwo, self).__init__(save_path=save_path, year_initial=year_initial, year_conclude=year_conclude, address=address)

    '''
    Second method, we want to get ten years data in one time.
    '''

    def get_job_date(self, worker):
        if worker[-3:].isdigit():
            mul = int(int(worker[-3:]) / 12)
            arg_month = int(worker[-3:]) % 12
            month_begin = 1 + 1 * arg_month
            month_finish = 2 + 1 * arg_month
            year_begin = self.year_initial + 1 * mul
            year_finish = self.year_conclude + 1 * mul
            url_pool, date_list = self.get_url(year_begin, year_finish, month_begin, month_finish, 1, 32)
            return url_pool, date_list
        else:
            print('Please check your name of variable \'worker\', the last 3 string is not integer.')
            ans = input('Do you want to stop the program ? (Yes/No)')
            if 'y' in ans or 'Y' in ans:
                sys.exit()
            else:
                print('Program keep operating.')

    '''
    This function aim to get ten years data in one time
    '''

    def open_file(self, worker):
        if worker[-3:].isdigit():
            mul = int(int(worker[-3:]) / 12)
            year = self.year_initial + 1 * mul
            file = self.path + str(year) + '/weather-' + str(int(int(worker[-3:]) % 12) + 1) + '-month.csv'
            csv_file = open(file, 'a+', newline='', encoding='utf-8-sig')
            write_file = csv.writer(csv_file)
            return csv_file, write_file
        else:
            print('Please check your name of variable \'worker\', the last 3 string is not integer.')
            ans = input('Do you want to stop the program ? (Yes/No)')
            if 'y' in ans or 'Y' in ans:
                sys.exit()
            else:
                print('Program keep operating.')

# %%
class PrepositiveMeasureVerThree(AllUrlInWorker):
    def __init__(self, save_path, year_initial, year_conclude, address):
        super(PrepositiveMeasureVerThree, self).__init__(save_path=save_path, year_initial=year_initial, year_conclude=year_conclude, address=address)

    '''
    Third method, we want to use more threads to get ten years data in one time.
    '''

    '''
    Question : Is it better? More faster?
    Answer 1 :  We crawl from 2009 to 2011 about 2 years and 1 month, took 16.278 seconds
    Answer 2 : We crawl from 2009 to 2013 about 4 years and 1 month, took 30.092 seconds
    Answer 3 : We crawl from 2013 to 2017 about 4 years, took 36.027 seconds
    we can pay attention to the average time of it spend in all time, unfortunately, it is a little slower than the
    situation that we use less threads
    '''

    def get_job_date(self, worker):
        if worker[-3:].isdigit():
            mul = int(int(worker[-3:]) / 24)
            arg_month = int(worker[-3:]) % 24
            if arg_month < 12:
                day_begin = 1
                day_finish = 17
                month_begin = 1 + 1 * arg_month
                month_finish = 2 + 1 * arg_month
            else:
                new_arg_month = arg_month - 12
                day_begin = 17
                day_finish = 32
                month_begin = 1 + 1 * new_arg_month
                month_finish = 2 + 1 * new_arg_month
            year_begin = self.year_initial + 1 * mul
            year_finish = self.year_conclude + 1 * mul
            url_pool, date_list = self.get_url(year_begin, year_finish, month_begin, month_finish, day_begin,
                                               day_finish)
            return url_pool, date_list
        else:
            print('Please check your name of variable \'worker\', the last 3 string is not integer.')
            ans = input('Do you want to stop the program ? (Yes/No)')
            if 'y' in ans or 'Y' in ans:
                sys.exit()
            else:
                print('Program keep operating.')


    def open_file(self, worker):
        if worker[-3:].isdigit():
            mul = int(int(worker[-3:]) / 24)
            year = self.year_initial + 1 * mul
            if int(int(worker[-3:]) % 24) < 12:
                file = self.path + str(year) + '/weather-' + str(
                    int(int(worker[-3:]) % 24) + 1) + '-month-first-two-weeks.csv'
                csv_file = open(file, 'a+', newline='', encoding='utf-8-sig')
                write_file = csv.writer(csv_file)
                return csv_file, write_file
            else:
                file = self.path + str(year) + '/weather-' + str(
                    int(int(worker[-3:]) % 24) - 11) + '-month-second-two-weeks.csv'
                csv_file = open(file, 'a+', newline='', encoding='utf-8-sig')
                write_file = csv.writer(csv_file)
                return csv_file, write_file
        else:
            print('Please check your name of variable \'worker\', the last 3 string is not integer.')
            ans = input('Do you want to stop the program ? (Yes/No)')
            if 'y' in ans or 'Y' in ans:
                sys.exit()
            else:
                print('Program keep operating.')

# %%
class BsCrawler(FakeIdentity, PrepositiveMeasureVerTwo):
    def parser(self, target_url_pool, date_list, write_in_file, worker):
        index = 0
        for url in target_url_pool:
#             index += 1
            html = requests.get(url, headers=self.get_header())
            if html.status_code == requests.codes.ok:
                soup = BeautifulSoup(html.text, 'html.parser')
                web_data = soup.select('tbody > tr')[0].text
                if web_data == 'No data available for the given date. Try selecting a different day.':
                    print('-------------------------')
                    print('There is nothing in this data.')
                    print('-------------------------')
                    for date in date_list:
                        if date in url:
                            date_list.remove(date)
                    pass
                else:
                    tableRow = soup.select('tbody > tr')
#                     all_count = int(len(tableRow)) * int(len(url_pool))
#                     row_count = 1
                    for row in tableRow:
                        Time = row.select_one('th').text
                        # Time = row.select('th')[0].text
                        newTime = Time[0:5]
                        weather = row.select('.mtt')[0].get('title')
                        Temp = row.select_one('.wt-ic + td').text
                        wind = row.select('.sep')[0].text
                        Barometer = row.select('.sep')[1].text
                        wind_dir = row.select('.comp')[0].get('title')
                        Bar = row.select('.sep')[1]
                        Humidity = Bar.find_previous_siblings('td')[0].text
                        Bar = row.select('.sep')[1]
                        Visibility = Bar.find_next_siblings('td')[0].text

                        nws = [newTime, weather, Temp, wind, Barometer, wind_dir, Humidity, Visibility]
                        nws.insert(0, date_list[index])
                        write_in_file.writerow(nws)
                        # time.sleep(random.randint(random.randint(1, 4) + random.randint(2, 3), random.randint(4, 13) + random.randint(4, 7)))
#                         sys.stdout.write("\r %-100s [%d%%]" % ('>' * int((index * row_count) / 7) , (100 / all_count) * index * row_count))
#                         row_count += 1
                    index += 1
                    if index == 1:
                        print('The data of ' + str(index) + 'st day has been recorded success ! - ' + str(worker))
                    elif index == 2:
                        print('The data of ' + str(index) + 'nd day has been recorded success ! - ' + str(worker))
                    elif index == 3:
                        print('The data of ' + str(index) + 'rd day has been recorded success ! - ' + str(worker))
                    else:
                        print('The data of ' + str(index) + 'th day has been recorded success ! - ' + str(worker))


    @threads(120)
    def main_job(self, worker):
        crawl_start_time = time.time()

        fields = (x for x in ['Date', 'Time', 'Weather', 'Temperature', 'Wind', 'Barometer', 'Wind Direction', 'Humidity', 'Visibility'])
        csv_file, write_file = self.open_file(worker)
        write_file.writerow(fields)
        url_pool, date_list = self.get_job_date(worker)
        self.parser(url_pool, date_list, write_file, worker)
        csv_file.close()

        crawl_end_time = time.time()
        print('------------------------')
        print('Total time: ' + str(crawl_end_time - crawl_start_time) + ' seconds. - ' + str(worker))
        print('Crawler Finish. - ' + str(worker))
        print('------------------------')

# %%
if __name__ == '__main__':
    print('Program start.')

    threads_num = 120       # You can change 120 to 1 or 240 to observe the results. And remember, if you alter,besides
                            # you should to alter the number of lebal in line 341, you have to alter class BsCrawler
                            # inherit from which one of class.
    year_start = 2009       # You can change to the year you want to crawl
    year_end = 2010
    crawl_address = 'san-jose'    # The data of weather in address where you want to crawl.
    path = r'C:\Users\iAirJordan\Desktop\jupyter-data\weather-mountain-view-multithreading\mountain-view-weather-'

    '''
    Check the path is exit or not, if not, then build it.
    '''
    for year in range(year_start, year_start + int(threads_num / 12)):
        folder = os.path.exists(path + str(year) + '/')
        if not folder:
            os.makedirs(path + str(year) + '/')
            print(path + str(year) + '/')
            print('Build folder success !!!')

    bs_crawler = BsCrawler(save_path=path, year_initial=year_start, year_conclude=year_end, address=crawl_address)

    workers_list = [('worker-' + str('%003d' % num)) for num in range(threads_num)]
    for j in workers_list:
        bs_crawler.main_job(j)

    print('finish')
# Out:
# Program start.
# C:\Users\iAirJordan\Desktop\jupyter-data\weather-mountain-view-multithreading\mountain-view-weather-2009/
# Build folder success !!!
# C:\Users\iAirJordan\Desktop\jupyter-data\weather-mountain-view-multithreading\mountain-view-weather-2010/
# Build folder success !!!
# C:\Users\iAirJordan\Desktop\jupyter-data\weather-mountain-view-multithreading\mountain-view-weather-2011/
# Build folder success !!!
# C:\Users\iAirJordan\Desktop\jupyter-data\weather-mountain-view-multithreading\mountain-view-weather-2012/
# Build folder success !!!
# C:\Users\iAirJordan\Desktop\jupyter-data\weather-mountain-view-multithreading\mountain-view-weather-2013/
# Build folder success !!!
# C:\Users\iAirJordan\Desktop\jupyter-data\weather-mountain-view-multithreading\mountain-view-weather-2014/
# Build folder success !!!
# C:\Users\iAirJordan\Desktop\jupyter-data\weather-mountain-view-multithreading\mountain-view-weather-2015/
# Build folder success !!!
# C:\Users\iAirJordan\Desktop\jupyter-data\weather-mountain-view-multithreading\mountain-view-weather-2016/
# Build folder success !!!
# C:\Users\iAirJordan\Desktop\jupyter-data\weather-mountain-view-multithreading\mountain-view-weather-2017/
# Build folder success !!!
# C:\Users\iAirJordan\Desktop\jupyter-data\weather-mountain-view-multithreading\mountain-view-weather-2018/
# Build folder success !!!
# finish
# The data of 1st day has been recorded success ! - worker-050The data of 1st day has been recorded success ! - worker-035
#
# -------------------------
# There is nothing in this data.
# -------------------------
# The data of 1st day has been recorded success ! - worker-034The data of 1st day has been recorded success ! - worker-022
# The data of 1st day has been recorded success ! - worker-011
# -------------------------
#
# There is nothing in this data.
# -------------------------
# -------------------------The data of 1st day has been recorded success ! - worker-065
# There is nothing in this data.
# -------------------------
#
# The data of 1st day has been recorded success ! - worker-063
# The data of 1st day has been recorded success ! - worker-010
# The data of 1st day has been recorded success ! - worker-071The data of 1st day has been recorded success ! - worker-025
#
# The data of 1st day has been recorded success ! - worker-109The data of 1st day has been recorded success ! - worker-039
# The data of 1st day has been recorded success ! - worker-074
# The data of 1st day has been recorded success ! - worker-044
# The data of 1st day has been recorded success ! - worker-114The data of 1st day has been recorded success ! - worker-064
#
#
# The data of 1st day has been recorded success ! - worker-058
# The data of 1st day has been recorded success ! - worker-049
# The data of 1st day has been recorded success ! - worker-091The data of 1st day has been recorded success ! - worker-067
# The data of 1st day has been recorded success ! - worker-084
# The data of 1st day has been recorded success ! - worker-082
#
# The data of 1st day has been recorded success ! - worker-060
# The data of 1st day has been recorded success ! - worker-030
# The data of 1st day has been recorded success ! - worker-072
# -------------------------The data of 1st day has been recorded success ! - worker-085The data of 1st day has been recorded success ! - worker-028
# There is nothing in this data.The data of 1st day has been recorded success ! - worker-115
#
# The data of 1st day has been recorded success ! - worker-059-------------------------The data of 1st day has been recorded success ! - worker-066The data of 1st day has been recorded success ! - worker-073The data of 1st day has been recorded success ! - worker-081
#
#
#
#
#
#
# -------------------------The data of 1st day has been recorded success ! - worker-117
#
# There is nothing in this data.
# The data of 1st day has been recorded success ! - worker-092The data of 1st day has been recorded success ! - worker-012
# -------------------------
#
# The data of 1st day has been recorded success ! - worker-061
# The data of 1st day has been recorded success ! - worker-048-------------------------
#
# There is nothing in this data.
# -------------------------
# The data of 1st day has been recorded success ! - worker-052
# The data of 1st day has been recorded success ! - worker-013The data of 1st day has been recorded success ! - worker-112
#
# The data of 1st day has been recorded success ! - worker-096The data of 1st day has been recorded success ! - worker-090
#
# The data of 1st day has been recorded success ! - worker-118The data of 1st day has been recorded success ! - worker-113
#
# The data of 1st day has been recorded success ! - worker-023
# The data of 1st day has been recorded success ! - worker-116
# The data of 1st day has been recorded success ! - worker-079
# The data of 1st day has been recorded success ! - worker-093
# The data of 1st day has been recorded success ! - worker-020The data of 1st day has been recorded success ! - worker-062
#
# The data of 1st day has been recorded success ! - worker-104-------------------------
# There is nothing in this data.
# -------------------------
# The data of 1st day has been recorded success ! - worker-098
#
# The data of 1st day has been recorded success ! - worker-106The data of 1st day has been recorded success ! - worker-016
# The data of 1st day has been recorded success ! - worker-041The data of 1st day has been recorded success ! - worker-076
#
#
# The data of 1st day has been recorded success ! - worker-075The data of 1st day has been recorded success ! - worker-054The data of 1st day has been recorded success ! - worker-111The data of 1st day has been recorded success ! - worker-097
#
#
#
# The data of 1st day has been recorded success ! - worker-087
# The data of 1st day has been recorded success ! - worker-047The data of 1st day has been recorded success ! - worker-103-------------------------
# There is nothing in this data.
# -------------------------
# The data of 1st day has been recorded success ! - worker-038
#
# The data of 1st day has been recorded success ! - worker-083
#
# The data of 1st day has been recorded success ! - worker-032
# The data of 1st day has been recorded success ! - worker-019
# The data of 1st day has been recorded success ! - worker-068The data of 1st day has been recorded success ! - worker-040
# The data of 1st day has been recorded success ! - worker-070
# The data of 1st day has been recorded success ! - worker-037The data of 1st day has been recorded success ! - worker-080
#
# The data of 1st day has been recorded success ! - worker-086The data of 1st day has been recorded success ! - worker-046The data of 1st day has been recorded success ! - worker-056
# The data of 1st day has been recorded success ! - worker-045
#
# The data of 1st day has been recorded success ! - worker-051
# The data of 1st day has been recorded success ! - worker-029The data of 1st day has been recorded success ! - worker-108
# -------------------------
# There is nothing in this data.
# -------------------------
#
# The data of 1st day has been recorded success ! - worker-101
#
# The data of 1st day has been recorded success ! - worker-053
#
# The data of 1st day has been recorded success ! - worker-021The data of 1st day has been recorded success ! - worker-057The data of 1st day has been recorded success ! - worker-018
#
#
# The data of 1st day has been recorded success ! - worker-015The data of 1st day has been recorded success ! - worker-119
# The data of 1st day has been recorded success ! - worker-043
#
# The data of 1st day has been recorded success ! - worker-042
# The data of 1st day has been recorded success ! - worker-099-------------------------
#
# There is nothing in this data.The data of 1st day has been recorded success ! - worker-095
# -------------------------
# The data of 1st day has been recorded success ! - worker-033The data of 1st day has been recorded success ! - worker-017
# The data of 1st day has been recorded success ! - worker-100
#
#
# The data of 1st day has been recorded success ! - worker-031-------------------------
# There is nothing in this data.
# -------------------------
#
# The data of 1st day has been recorded success ! - worker-107-------------------------
# There is nothing in this data.
# -------------------------
#
# The data of 1st day has been recorded success ! - worker-088
# The data of 1st day has been recorded success ! - worker-089
# The data of 1st day has been recorded success ! - worker-055The data of 1st day has been recorded success ! - worker-009The data of 2nd day has been recorded success ! - worker-025
#
#
# The data of 1st day has been recorded success ! - worker-110
# -------------------------
# There is nothing in this data.
# -------------------------
# The data of 1st day has been recorded success ! - worker-105
# The data of 1st day has been recorded success ! - worker-102
# The data of 1st day has been recorded success ! - worker-036-------------------------
# There is nothing in this data.
# -------------------------
# The data of 1st day has been recorded success ! - worker-077
#
# -------------------------
# The data of 2nd day has been recorded success ! - worker-011There is nothing in this data.
#
# -------------------------
# The data of 1st day has been recorded success ! - worker-069
# The data of 2nd day has been recorded success ! - worker-034
# The data of 1st day has been recorded success ! - worker-014
# The data of 2nd day has been recorded success ! - worker-010The data of 2nd day has been recorded success ! - worker-114
# The data of 2nd day has been recorded success ! - worker-039
#
# The data of 2nd day has been recorded success ! - worker-064
# The data of 2nd day has been recorded success ! - worker-059The data of 2nd day has been recorded success ! - worker-022The data of 2nd day has been recorded success ! - worker-050
# The data of 2nd day has been recorded success ! - worker-067The data of 2nd day has been recorded success ! - worker-063
# The data of 1st day has been recorded success ! - worker-078
#
#
#
# The data of 2nd day has been recorded success ! - worker-035The data of 2nd day has been recorded success ! - worker-091The data of 2nd day has been recorded success ! - worker-071The data of 2nd day has been recorded success ! - worker-044-------------------------
# There is nothing in this data.
# -------------------------
#
#
# The data of 2nd day has been recorded success ! - worker-117
#
# The data of 2nd day has been recorded success ! - worker-065The data of 2nd day has been recorded success ! - worker-085
# The data of 2nd day has been recorded success ! - worker-109
#
#
# The data of 2nd day has been recorded success ! - worker-058
# The data of 2nd day has been recorded success ! - worker-074
# The data of 2nd day has been recorded success ! - worker-049The data of 2nd day has been recorded success ! - worker-030
#
# The data of 2nd day has been recorded success ! - worker-082The data of 2nd day has been recorded success ! - worker-115
#
# -------------------------
# There is nothing in this data.
# The data of 2nd day has been recorded success ! - worker-048-------------------------The data of 2nd day has been recorded success ! - worker-028-------------------------
#
#
# The data of 2nd day has been recorded success ! - worker-090
# The data of 2nd day has been recorded success ! - worker-073The data of 2nd day has been recorded success ! - worker-084
#
# There is nothing in this data.
# -------------------------The data of 2nd day has been recorded success ! - worker-081
#
#
# The data of 2nd day has been recorded success ! - worker-060
# The data of 2nd day has been recorded success ! - worker-052The data of 2nd day has been recorded success ! - worker-118
#
# The data of 2nd day has been recorded success ! - worker-072
# The data of 2nd day has been recorded success ! - worker-062The data of 1st day has been recorded success ! - worker-024
#
# The data of 2nd day has been recorded success ! - worker-092The data of 2nd day has been recorded success ! - worker-066The data of 2nd day has been recorded success ! - worker-012
# The data of 2nd day has been recorded success ! - worker-023
#
#
# The data of 2nd day has been recorded success ! - worker-106The data of 2nd day has been recorded success ! - worker-096
#
# The data of 2nd day has been recorded success ! - worker-061
# The data of 2nd day has been recorded success ! - worker-113
# The data of 2nd day has been recorded success ! - worker-112
# The data of 2nd day has been recorded success ! - worker-093
# The data of 2nd day has been recorded success ! - worker-097The data of 2nd day has been recorded success ! - worker-076
#
# The data of 2nd day has been recorded success ! - worker-013The data of 2nd day has been recorded success ! - worker-054
# The data of 2nd day has been recorded success ! - worker-079
# The data of 2nd day has been recorded success ! - worker-020
# The data of 2nd day has been recorded success ! - worker-111
# The data of 2nd day has been recorded success ! - worker-075
# The data of 2nd day has been recorded success ! - worker-019
# The data of 2nd day has been recorded success ! - worker-038
#
# The data of 2nd day has been recorded success ! - worker-068
# The data of 2nd day has been recorded success ! - worker-116The data of 2nd day has been recorded success ! - worker-098
# The data of 2nd day has been recorded success ! - worker-016
#
# The data of 2nd day has been recorded success ! - worker-045
# The data of 2nd day has been recorded success ! - worker-041
# The data of 2nd day has been recorded success ! - worker-103
# The data of 2nd day has been recorded success ! - worker-015-------------------------
#
# The data of 2nd day has been recorded success ! - worker-032
# There is nothing in this data.
# -------------------------The data of 2nd day has been recorded success ! - worker-095
#
# The data of 2nd day has been recorded success ! - worker-080
# The data of 2nd day has been recorded success ! - worker-042The data of 2nd day has been recorded success ! - worker-100The data of 2nd day has been recorded success ! - worker-056The data of 2nd day has been recorded success ! - worker-033
# -------------------------
# There is nothing in this data.
# -------------------------
#
# The data of 2nd day has been recorded success ! - worker-037The data of 2nd day has been recorded success ! - worker-040
#
#
# The data of 2nd day has been recorded success ! - worker-099The data of 2nd day has been recorded success ! - worker-021
# The data of 2nd day has been recorded success ! - worker-057The data of 2nd day has been recorded success ! - worker-108The data of 2nd day has been recorded success ! - worker-101
#
#
# The data of 2nd day has been recorded success ! - worker-047
#
# The data of 2nd day has been recorded success ! - worker-119
# -------------------------
# There is nothing in this data.
# -------------------------
# The data of 2nd day has been recorded success ! - worker-043The data of 2nd day has been recorded success ! - worker-051
# The data of 2nd day has been recorded success ! - worker-053
#
# The data of 2nd day has been recorded success ! - worker-046
#
# The data of 2nd day has been recorded success ! - worker-070
# The data of 2nd day has been recorded success ! - worker-017
# The data of 2nd day has been recorded success ! - worker-018The data of 1st day has been recorded success ! - worker-094
# The data of 2nd day has been recorded success ! - worker-029
#
# -------------------------The data of 2nd day has been recorded success ! - worker-104
#
# There is nothing in this data.
# -------------------------
# The data of 2nd day has been recorded success ! - worker-087
# The data of 2nd day has been recorded success ! - worker-086The data of 2nd day has been recorded success ! - worker-083The data of 2nd day has been recorded success ! - worker-036
#
#
# The data of 2nd day has been recorded success ! - worker-009
# -------------------------The data of 2nd day has been recorded success ! - worker-089
# There is nothing in this data.
# The data of 2nd day has been recorded success ! - worker-055--------------------------------------------------
#
#
# There is nothing in this data.
# The data of 3rd day has been recorded success ! - worker-063The data of 3rd day has been recorded success ! - worker-010
# The data of 2nd day has been recorded success ! - worker-014
# -------------------------
# The data of 3rd day has been recorded success ! - worker-064-------------------------The data of 2nd day has been recorded success ! - worker-088
#
# There is nothing in this data.-------------------------
# There is nothing in this data.
# -------------------------
#
#
# The data of 3rd day has been recorded success ! - worker-011
# -------------------------
# The data of 2nd day has been recorded success ! - worker-077The data of 2nd day has been recorded success ! - worker-102The data of 3rd day has been recorded success ! - worker-111
#
#
# The data of 2nd day has been recorded success ! - worker-031
# The data of 2nd day has been recorded success ! - worker-110
#
# The data of 3rd day has been recorded success ! - worker-044
# The data of 2nd day has been recorded success ! - worker-107
#
# -------------------------
# There is nothing in this data.
# -------------------------
# The data of 2nd day has been recorded success ! - worker-105
# The data of 3rd day has been recorded success ! - worker-039
# The data of 3rd day has been recorded success ! - worker-114
# The data of 3rd day has been recorded success ! - worker-034
# The data of 3rd day has been recorded success ! - worker-082The data of 3rd day has been recorded success ! - worker-067
#
# The data of 3rd day has been recorded success ! - worker-049The data of 2nd day has been recorded success ! - worker-069
#
# The data of 3rd day has been recorded success ! - worker-058
# The data of 3rd day has been recorded success ! - worker-115
# The data of 3rd day has been recorded success ! - worker-109
# The data of 3rd day has been recorded success ! - worker-035
# The data of 3rd day has been recorded success ! - worker-030The data of 3rd day has been recorded success ! - worker-090The data of 3rd day has been recorded success ! - worker-050
#
# The data of 3rd day has been recorded success ! - worker-117The data of 3rd day has been recorded success ! - worker-065-------------------------
# There is nothing in this data.
# The data of 3rd day has been recorded success ! - worker-091
#
# The data of 3rd day has been recorded success ! - worker-022
#
#
# -------------------------
# The data of 3rd day has been recorded success ! - worker-059
# -------------------------
# The data of 3rd day has been recorded success ! - worker-085The data of 3rd day has been recorded success ! - worker-081
# There is nothing in this data.
# -------------------------
# The data of 3rd day has been recorded success ! - worker-052
# The data of 3rd day has been recorded success ! - worker-072
# The data of 3rd day has been recorded success ! - worker-048The data of 3rd day has been recorded success ! - worker-084
#
#
# The data of 3rd day has been recorded success ! - worker-073The data of 2nd day has been recorded success ! - worker-078The data of 3rd day has been recorded success ! - worker-106The data of 2nd day has been recorded success ! - worker-024The data of 3rd day has been recorded success ! - worker-071
# The data of 3rd day has been recorded success ! - worker-096The data of 3rd day has been recorded success ! - worker-118
# The data of 3rd day has been recorded success ! - worker-074
# The data of 3rd day has been recorded success ! - worker-060
# The data of 3rd day has been recorded success ! - worker-113
#
#
#
#
#
# The data of 3rd day has been recorded success ! - worker-061The data of 3rd day has been recorded success ! - worker-093
#
# The data of 3rd day has been recorded success ! - worker-076The data of 3rd day has been recorded success ! - worker-023
#
# The data of 3rd day has been recorded success ! - worker-019
# The data of 3rd day has been recorded success ! - worker-092
# The data of 3rd day has been recorded success ! - worker-012The data of 3rd day has been recorded success ! - worker-062
# The data of 3rd day has been recorded success ! - worker-038-------------------------
# There is nothing in this data.
# -------------------------
#
# The data of 3rd day has been recorded success ! - worker-112The data of 3rd day has been recorded success ! - worker-013
#
# The data of 4th day has been recorded success ! - worker-030
# The data of 3rd day has been recorded success ! - worker-054
# The data of 3rd day has been recorded success ! - worker-066
# The data of 3rd day has been recorded success ! - worker-097
# The data of 3rd day has been recorded success ! - worker-116
# The data of 3rd day has been recorded success ! - worker-016
# The data of 3rd day has been recorded success ! - worker-079
# The data of 3rd day has been recorded success ! - worker-098The data of 3rd day has been recorded success ! - worker-041
#
# The data of 3rd day has been recorded success ! - worker-045
# The data of 3rd day has been recorded success ! - worker-020
# The data of 3rd day has been recorded success ! - worker-068
# The data of 3rd day has been recorded success ! - worker-042The data of 3rd day has been recorded success ! - worker-095The data of 3rd day has been recorded success ! - worker-015
# -------------------------
# There is nothing in this data.
# -------------------------
#
#
# -------------------------The data of 3rd day has been recorded success ! - worker-021
# There is nothing in this data.
# The data of 3rd day has been recorded success ! - worker-032
# -------------------------
# There is nothing in this data.
# -------------------------
# The data of 3rd day has been recorded success ! - worker-103
# The data of 3rd day has been recorded success ! - worker-037The data of 3rd day has been recorded success ! - worker-108
#
# -------------------------
#
# The data of 3rd day has been recorded success ! - worker-033
# The data of 3rd day has been recorded success ! - worker-101
# The data of 3rd day has been recorded success ! - worker-040
# The data of 3rd day has been recorded success ! - worker-100
# The data of 3rd day has been recorded success ! - worker-056
# The data of 3rd day has been recorded success ! - worker-046The data of 3rd day has been recorded success ! - worker-099The data of 3rd day has been recorded success ! - worker-047
#
#
# The data of 3rd day has been recorded success ! - worker-017
# The data of 3rd day has been recorded success ! - worker-080
# The data of 3rd day has been recorded success ! - worker-053
# The data of 1st day has been recorded success ! - worker-026
# The data of 3rd day has been recorded success ! - worker-029
# The data of 3rd day has been recorded success ! - worker-018The data of 2nd day has been recorded success ! - worker-094
# The data of 3rd day has been recorded success ! - worker-087
#
# The data of 3rd day has been recorded success ! - worker-070The data of 3rd day has been recorded success ! - worker-043The data of 3rd day has been recorded success ! - worker-057
#
#
# The data of 3rd day has been recorded success ! - worker-036The data of 3rd day has been recorded success ! - worker-119
#
# -------------------------
# There is nothing in this data.
# -------------------------
# The data of 3rd day has been recorded success ! - worker-051
# -------------------------
# There is nothing in this data.
# -------------------------
# -------------------------
# There is nothing in this data.
# -------------------------
# -------------------------The data of 3rd day has been recorded success ! - worker-025
#
# There is nothing in this data.The data of 3rd day has been recorded success ! - worker-083
# -------------------------
# The data of 4th day has been recorded success ! - worker-010
#
# The data of 3rd day has been recorded success ! - worker-104The data of 4th day has been recorded success ! - worker-044
#
# The data of 4th day has been recorded success ! - worker-063The data of 3rd day has been recorded success ! - worker-089
# The data of 3rd day has been recorded success ! - worker-077
# The data of 3rd day has been recorded success ! - worker-086The data of 3rd day has been recorded success ! - worker-102
#
# The data of 3rd day has been recorded success ! - worker-088The data of 4th day has been recorded success ! - worker-011
#
# The data of 3rd day has been recorded success ! - worker-055
#
# The data of 3rd day has been recorded success ! - worker-014-------------------------
# There is nothing in this data.
# -------------------------
# The data of 4th day has been recorded success ! - worker-064
#
# The data of 4th day has been recorded success ! - worker-039The data of 4th day has been recorded success ! - worker-111
# The data of 4th day has been recorded success ! - worker-067The data of 4th day has been recorded success ! - worker-058
# The data of 3rd day has been recorded success ! - worker-031
# The data of 3rd day has been recorded success ! - worker-105The data of 4th day has been recorded success ! - worker-114
#
# The data of 4th day has been recorded success ! - worker-049
# The data of 3rd day has been recorded success ! - worker-107
#
# The data of 4th day has been recorded success ! - worker-082
#
# The data of 4th day has been recorded success ! - worker-034
# -------------------------
# The data of 3rd day has been recorded success ! - worker-075There is nothing in this data.
#
# -------------------------
# The data of 4th day has been recorded success ! - worker-109-------------------------
#
# There is nothing in this data.
# -------------------------
# The data of 4th day has been recorded success ! - worker-050
# The data of 3rd day has been recorded success ! - worker-069
# The data of 4th day has been recorded success ! - worker-065The data of 3rd day has been recorded success ! - worker-110
#
# The data of 4th day has been recorded success ! - worker-091
# The data of 4th day has been recorded success ! - worker-085The data of 4th day has been recorded success ! - worker-115
#
# The data of 4th day has been recorded success ! - worker-022
# The data of 4th day has been recorded success ! - worker-035
# The data of 4th day has been recorded success ! - worker-052
# The data of 4th day has been recorded success ! - worker-117
# The data of 3rd day has been recorded success ! - worker-078
# The data of 4th day has been recorded success ! - worker-084
# The data of 4th day has been recorded success ! - worker-073
# The data of 4th day has been recorded success ! - worker-059
# The data of 4th day has been recorded success ! - worker-072
# The data of 4th day has been recorded success ! - worker-081
# The data of 4th day has been recorded success ! - worker-048
# The data of 4th day has been recorded success ! - worker-113
# -------------------------
# There is nothing in this data.
# -------------------------
# The data of 4th day has been recorded success ! - worker-060
# The data of 4th day has been recorded success ! - worker-093
# The data of 3rd day has been recorded success ! - worker-028
# The data of 4th day has been recorded success ! - worker-090
# The data of 4th day has been recorded success ! - worker-019
# The data of 4th day has been recorded success ! - worker-071
# The data of 4th day has been recorded success ! - worker-092The data of 4th day has been recorded success ! - worker-038
# The data of 5th day has been recorded success ! - worker-030
#
# The data of 4th day has been recorded success ! - worker-054The data of 4th day has been recorded success ! - worker-062
#
# The data of 4th day has been recorded success ! - worker-106The data of 4th day has been recorded success ! - worker-079The data of 4th day has been recorded success ! - worker-023
#
#
# The data of 4th day has been recorded success ! - worker-074The data of 4th day has been recorded success ! - worker-112
#
# The data of 4th day has been recorded success ! - worker-096The data of 4th day has been recorded success ! - worker-066
#
# The data of 4th day has been recorded success ! - worker-012The data of 4th day has been recorded success ! - worker-061
#
# The data of 4th day has been recorded success ! - worker-013The data of 4th day has been recorded success ! - worker-045
# The data of 4th day has been recorded success ! - worker-097The data of 4th day has been recorded success ! - worker-118
# -------------------------The data of 4th day has been recorded success ! - worker-076The data of 4th day has been recorded success ! - worker-116
#
# The data of 4th day has been recorded success ! - worker-021
# There is nothing in this data.
# -------------------------
#
#
#
# -------------------------
# There is nothing in this data.
# -------------------------
# The data of 4th day has been recorded success ! - worker-103The data of 4th day has been recorded success ! - worker-042The data of 4th day has been recorded success ! - worker-098The data of 4th day has been recorded success ! - worker-015
#
#
# The data of 4th day has been recorded success ! - worker-068The data of 4th day has been recorded success ! - worker-041
# The data of 4th day has been recorded success ! - worker-016
#
#
# The data of 4th day has been recorded success ! - worker-095
# The data of 4th day has been recorded success ! - worker-033The data of 4th day has been recorded success ! - worker-040
#
# The data of 4th day has been recorded success ! - worker-037
# The data of 4th day has been recorded success ! - worker-032
# The data of 4th day has been recorded success ! - worker-020
# -------------------------
# There is nothing in this data.
# -------------------------
# The data of 4th day has been recorded success ! - worker-100-------------------------The data of 4th day has been recorded success ! - worker-018The data of 4th day has been recorded success ! - worker-017
# The data of 4th day has been recorded success ! - worker-099
#
# There is nothing in this data.
# -------------------------
# The data of 4th day has been recorded success ! - worker-056The data of 4th day has been recorded success ! - worker-046
#
#
# The data of 4th day has been recorded success ! - worker-119The data of 4th day has been recorded success ! - worker-053
# The data of 4th day has been recorded success ! - worker-101The data of 3rd day has been recorded success ! - worker-094
#
#
#
# The data of 4th day has been recorded success ! - worker-070The data of 4th day has been recorded success ! - worker-080
#
# The data of 4th day has been recorded success ! - worker-047
# The data of 4th day has been recorded success ! - worker-108
# The data of 4th day has been recorded success ! - worker-029
# -------------------------The data of 4th day has been recorded success ! - worker-025
# -------------------------The data of 4th day has been recorded success ! - worker-087
# There is nothing in this data.
# -------------------------
# The data of 4th day has been recorded success ! - worker-043
#
# -------------------------There is nothing in this data.
# -------------------------
#
# The data of 4th day has been recorded success ! - worker-077
# There is nothing in this data.
# -------------------------
#
# -------------------------
# There is nothing in this data.
# -------------------------
# The data of 4th day has been recorded success ! - worker-104-------------------------
# There is nothing in this data.
# -------------------------
#
# The data of 4th day has been recorded success ! - worker-051
# -------------------------The data of 4th day has been recorded success ! - worker-057
# There is nothing in this data.
# -------------------------
#
# The data of 5th day has been recorded success ! - worker-044
# The data of 4th day has been recorded success ! - worker-036
# The data of 4th day has been recorded success ! - worker-102The data of 4th day has been recorded success ! - worker-086
#
# The data of 4th day has been recorded success ! - worker-088
# The data of 4th day has been recorded success ! - worker-089
# The data of 5th day has been recorded success ! - worker-039The data of 4th day has been recorded success ! - worker-055
#
# The data of 4th day has been recorded success ! - worker-083
# The data of 5th day has been recorded success ! - worker-063-------------------------The data of 5th day has been recorded success ! - worker-064
#
# There is nothing in this data.
# -------------------------
#
# The data of 5th day has been recorded success ! - worker-049
# The data of 5th day has been recorded success ! - worker-058The data of 5th day has been recorded success ! - worker-011
# The data of 5th day has been recorded success ! - worker-091
#
# The data of 5th day has been recorded success ! - worker-067
# The data of 5th day has been recorded success ! - worker-034The data of 4th day has been recorded success ! - worker-107
# The data of 5th day has been recorded success ! - worker-082
# The data of 5th day has been recorded success ! - worker-050
# The data of 5th day has been recorded success ! - worker-109
# The data of 5th day has been recorded success ! - worker-114
# The data of 5th day has been recorded success ! - worker-022
# -------------------------The data of 4th day has been recorded success ! - worker-069
# There is nothing in this data.
#
#
# -------------------------The data of 4th day has been recorded success ! - worker-031
#
# The data of 5th day has been recorded success ! - worker-085
# The data of 5th day has been recorded success ! - worker-052
# The data of 3rd day has been recorded success ! - worker-024
# The data of 4th day has been recorded success ! - worker-075The data of 5th day has been recorded success ! - worker-113-------------------------
# There is nothing in this data.
# -------------------------
#
#
# The data of 5th day has been recorded success ! - worker-059
# The data of 5th day has been recorded success ! - worker-111The data of 5th day has been recorded success ! - worker-065
# The data of 4th day has been recorded success ! - worker-014
# The data of 4th day has been recorded success ! - worker-105
#
# The data of 5th day has been recorded success ! - worker-115The data of 5th day has been recorded success ! - worker-117
#
# The data of 5th day has been recorded success ! - worker-093The data of 5th day has been recorded success ! - worker-060
# The data of 5th day has been recorded success ! - worker-072
#
# The data of 5th day has been recorded success ! - worker-084The data of 5th day has been recorded success ! - worker-081
#
# The data of 5th day has been recorded success ! - worker-038
# The data of 5th day has been recorded success ! - worker-090
# The data of 5th day has been recorded success ! - worker-073
# The data of 5th day has been recorded success ! - worker-035
# The data of 5th day has been recorded success ! - worker-112
# The data of 5th day has been recorded success ! - worker-048
# The data of 5th day has been recorded success ! - worker-054
# The data of 5th day has been recorded success ! - worker-019
# The data of 5th day has been recorded success ! - worker-062The data of 5th day has been recorded success ! - worker-096The data of 4th day has been recorded success ! - worker-078
#
# The data of 5th day has been recorded success ! - worker-012
#
# The data of 4th day has been recorded success ! - worker-028The data of 5th day has been recorded success ! - worker-074The data of 5th day has been recorded success ! - worker-061
# The data of 6th day has been recorded success ! - worker-030
#
#
# The data of 5th day has been recorded success ! - worker-092
# The data of 5th day has been recorded success ! - worker-106The data of 5th day has been recorded success ! - worker-023
#
# The data of 5th day has been recorded success ! - worker-021
# The data of 5th day has been recorded success ! - worker-040
# -------------------------
# The data of 5th day has been recorded success ! - worker-071The data of 5th day has been recorded success ! - worker-116There is nothing in this data.
#
#
# -------------------------
# The data of 5th day has been recorded success ! - worker-079
# The data of 5th day has been recorded success ! - worker-066
# The data of 5th day has been recorded success ! - worker-042
# -------------------------
# There is nothing in this data.
# -------------------------
# The data of 5th day has been recorded success ! - worker-103
# The data of 5th day has been recorded success ! - worker-015The data of 5th day has been recorded success ! - worker-013
# The data of 5th day has been recorded success ! - worker-097
# The data of 5th day has been recorded success ! - worker-016
# The data of 5th day has been recorded success ! - worker-118
#
# The data of 5th day has been recorded success ! - worker-037
# The data of 5th day has been recorded success ! - worker-041The data of 5th day has been recorded success ! - worker-045
#
# The data of 5th day has been recorded success ! - worker-095The data of 5th day has been recorded success ! - worker-100
# -------------------------
#
# The data of 4th day has been recorded success ! - worker-094-------------------------
#
# There is nothing in this data.There is nothing in this data.
#
# -------------------------
# The data of 5th day has been recorded success ! - worker-046-------------------------
#
# The data of 5th day has been recorded success ! - worker-099The data of 5th day has been recorded success ! - worker-017
# The data of 5th day has been recorded success ! - worker-068
#
# -------------------------
# There is nothing in this data.
# -------------------------
# The data of 5th day has been recorded success ! - worker-053
# The data of 5th day has been recorded success ! - worker-076The data of 5th day has been recorded success ! - worker-032
#
# The data of 5th day has been recorded success ! - worker-108
# The data of 5th day has been recorded success ! - worker-029The data of 5th day has been recorded success ! - worker-101
#
# The data of 5th day has been recorded success ! - worker-119The data of 4th day has been recorded success ! - worker-110
#
# The data of 5th day has been recorded success ! - worker-047
# The data of 5th day has been recorded success ! - worker-087-------------------------
# The data of 5th day has been recorded success ! - worker-020
#
# There is nothing in this data.
# -------------------------
# The data of 5th day has been recorded success ! - worker-025The data of 5th day has been recorded success ! - worker-080
#
# The data of 5th day has been recorded success ! - worker-033The data of 5th day has been recorded success ! - worker-056
#
# The data of 5th day has been recorded success ! - worker-070The data of 5th day has been recorded success ! - worker-077
# The data of 5th day has been recorded success ! - worker-098
# The data of 5th day has been recorded success ! - worker-018The data of 3rd day has been recorded success ! - worker-009
# -------------------------
# There is nothing in this data.
# -------------------------
# -------------------------
# There is nothing in this data.
# -------------------------
#
# The data of 5th day has been recorded success ! - worker-036The data of 5th day has been recorded success ! - worker-102The data of 5th day has been recorded success ! - worker-083
# The data of 6th day has been recorded success ! - worker-044
#
#
# The data of 6th day has been recorded success ! - worker-082The data of 5th day has been recorded success ! - worker-010
# -------------------------The data of 5th day has been recorded success ! - worker-051
# There is nothing in this data.
# -------------------------
#
#
# The data of 6th day has been recorded success ! - worker-091The data of 6th day has been recorded success ! - worker-064
#
# The data of 5th day has been recorded success ! - worker-043The data of 5th day has been recorded success ! - worker-057
#
# The data of 5th day has been recorded success ! - worker-089The data of 6th day has been recorded success ! - worker-114The data of 5th day has been recorded success ! - worker-069
#
#
# The data of 5th day has been recorded success ! - worker-088The data of 6th day has been recorded success ! - worker-039
# The data of 6th day has been recorded success ! - worker-049
# The data of 5th day has been recorded success ! - worker-086
#
# The data of 4th day has been recorded success ! - worker-024
# The data of 5th day has been recorded success ! - worker-055
# The data of 6th day has been recorded success ! - worker-067
# The data of 6th day has been recorded success ! - worker-063
# The data of 5th day has been recorded success ! - worker-107-------------------------
# There is nothing in this data.
#
# -------------------------
# -------------------------
# There is nothing in this data.
# -------------------------The data of 6th day has been recorded success ! - worker-022
#
# The data of 6th day has been recorded success ! - worker-058
# The data of 6th day has been recorded success ! - worker-113The data of 6th day has been recorded success ! - worker-065
#
# The data of 6th day has been recorded success ! - worker-109The data of 6th day has been recorded success ! - worker-050
# The data of 6th day has been recorded success ! - worker-059The data of 5th day has been recorded success ! - worker-104
#
#
# The data of 6th day has been recorded success ! - worker-034The data of 6th day has been recorded success ! - worker-011
#
# The data of 6th day has been recorded success ! - worker-060
# The data of 6th day has been recorded success ! - worker-085
# The data of 6th day has been recorded success ! - worker-111
# The data of 5th day has been recorded success ! - worker-105
# The data of 5th day has been recorded success ! - worker-031
# The data of 5th day has been recorded success ! - worker-075
# The data of 6th day has been recorded success ! - worker-052The data of 6th day has been recorded success ! - worker-115The data of 6th day has been recorded success ! - worker-112
#
# The data of 6th day has been recorded success ! - worker-117
#
# The data of 6th day has been recorded success ! - worker-090
# The data of 6th day has been recorded success ! - worker-073
# The data of 6th day has been recorded success ! - worker-093
# The data of 6th day has been recorded success ! - worker-084
# The data of 6th day has been recorded success ! - worker-048The data of 6th day has been recorded success ! - worker-038The data of 6th day has been recorded success ! - worker-054
#
# The data of 5th day has been recorded success ! - worker-028
#
# The data of 6th day has been recorded success ! - worker-019
# The data of 6th day has been recorded success ! - worker-012The data of 7th day has been recorded success ! - worker-030The data of 6th day has been recorded success ! - worker-062
# The data of 5th day has been recorded success ! - worker-014
# The data of 6th day has been recorded success ! - worker-072
#
#
# The data of 5th day has been recorded success ! - worker-078
# The data of 6th day has been recorded success ! - worker-074
# The data of 6th day has been recorded success ! - worker-021-------------------------The data of 6th day has been recorded success ! - worker-116
#
#
# There is nothing in this data.
# -------------------------
# The data of 6th day has been recorded success ! - worker-081
# The data of 6th day has been recorded success ! - worker-096The data of 6th day has been recorded success ! - worker-023-------------------------
# There is nothing in this data.
# -------------------------
#
#
# The data of 6th day has been recorded success ! - worker-040
# The data of 6th day has been recorded success ! - worker-061The data of 6th day has been recorded success ! - worker-079
#
# The data of 6th day has been recorded success ! - worker-071-------------------------
#
# There is nothing in this data.
# -------------------------
# The data of 6th day has been recorded success ! - worker-015
# The data of 6th day has been recorded success ! - worker-017
# The data of 6th day has been recorded success ! - worker-066
# The data of 6th day has been recorded success ! - worker-106The data of 6th day has been recorded success ! - worker-092
#
# The data of 5th day has been recorded success ! - worker-094
# The data of 6th day has been recorded success ! - worker-045
# The data of 6th day has been recorded success ! - worker-042
# The data of 6th day has been recorded success ! - worker-095The data of 7th day has been recorded success ! - worker-021
# The data of 6th day has been recorded success ! - worker-099-------------------------
# There is nothing in this data.
# -------------------------
# The data of 6th day has been recorded success ! - worker-053
# The data of 6th day has been recorded success ! - worker-046
#
# The data of 6th day has been recorded success ! - worker-032
#
# The data of 6th day has been recorded success ! - worker-037The data of 6th day has been recorded success ! - worker-016The data of 6th day has been recorded success ! - worker-041
# The data of 6th day has been recorded success ! - worker-118
# The data of 6th day has been recorded success ! - worker-097
#
#
# The data of 6th day has been recorded success ! - worker-101The data of 6th day has been recorded success ! - worker-119The data of 6th day has been recorded success ! - worker-013
#
# The data of 6th day has been recorded success ! - worker-010
# -------------------------
# -------------------------
#
# The data of 6th day has been recorded success ! - worker-108
# There is nothing in this data.The data of 6th day has been recorded success ! - worker-103The data of 6th day has been recorded success ! - worker-100
# The data of 6th day has been recorded success ! - worker-076
#
# The data of 6th day has been recorded success ! - worker-056
# There is nothing in this data.The data of 6th day has been recorded success ! - worker-047
# The data of 6th day has been recorded success ! - worker-098--------------------------------------------------
#
#
# The data of 6th day has been recorded success ! - worker-035
#
#
# The data of 6th day has been recorded success ! - worker-029
# The data of 6th day has been recorded success ! - worker-083The data of 5th day has been recorded success ! - worker-110
#
# The data of 6th day has been recorded success ! - worker-033-------------------------
# There is nothing in this data.
# -------------------------
#
# -------------------------
# There is nothing in this data.The data of 6th day has been recorded success ! - worker-068
#
# The data of 4th day has been recorded success ! - worker-009
# The data of 6th day has been recorded success ! - worker-070The data of 7th day has been recorded success ! - worker-064
# -------------------------
# -------------------------
#
# There is nothing in this data.
# -------------------------
# The data of 6th day has been recorded success ! - worker-077
# The data of 7th day has been recorded success ! - worker-044
# The data of 6th day has been recorded success ! - worker-018
# The data of 5th day has been recorded success ! - worker-024The data of 6th day has been recorded success ! - worker-087-------------------------
#
#
# There is nothing in this data.The data of 7th day has been recorded success ! - worker-091
# The data of 6th day has been recorded success ! - worker-102
#
# The data of 6th day has been recorded success ! - worker-057-------------------------
# The data of 6th day has been recorded success ! - worker-080
# The data of 7th day has been recorded success ! - worker-114
# The data of 6th day has been recorded success ! - worker-069
# The data of 6th day has been recorded success ! - worker-036
# The data of 7th day has been recorded success ! - worker-022
# The data of 7th day has been recorded success ! - worker-082
# The data of 6th day has been recorded success ! - worker-051
# The data of 7th day has been recorded success ! - worker-063
# The data of 7th day has been recorded success ! - worker-049The data of 7th day has been recorded success ! - worker-039
# The data of 7th day has been recorded success ! - worker-050
# -------------------------
# There is nothing in this data.
# -------------------------
# The data of 6th day has been recorded success ! - worker-107
#
# The data of 6th day has been recorded success ! - worker-043
# The data of 6th day has been recorded success ! - worker-075The data of 7th day has been recorded success ! - worker-067The data of 6th day has been recorded success ! - worker-055
# The data of 7th day has been recorded success ! - worker-085
#
#
# The data of 7th day has been recorded success ! - worker-058-------------------------
#
# There is nothing in this data.
# -------------------------
# The data of 6th day has been recorded success ! - worker-086The data of 7th day has been recorded success ! - worker-117The data of 7th day has been recorded success ! - worker-065
#
#
# The data of 7th day has been recorded success ! - worker-059The data of 7th day has been recorded success ! - worker-109The data of 7th day has been recorded success ! - worker-034
#
# ...
# There is nothing in this data.
# -------------------------
# -------------------------
# There is nothing in this data.
# -------------------------
# The data of 30th day has been recorded success ! - worker-020
#
#
#
# ------------------------
# Total time: 147.2347548007965 seconds. - worker-012The data of 29th day has been recorded success ! - worker-094
#
# ------------------------------------------------
# Crawler Finish. - worker-012------------------------
# Total time: 147.3085582256317 seconds. - worker-061
# Crawler Finish. - worker-061
# ------------------------
#
# Total time: 147.30955862998962 seconds. - worker-039The data of 31th day has been recorded success ! - worker-038
# ------------------------
# Total time: 147.3654079437256 seconds. - worker-038
# Crawler Finish. - worker-038
# Crawler Finish. - worker-039
# ------------------------
# The data of 30th day has been recorded success ! - worker-068
#
# Total time: 147.29758644104004 seconds. - worker-093
# Crawler Finish. - worker-093
# ------------------------
#
# ------------------------The data of 30th day has been recorded success ! - worker-096The data of 31th day has been recorded success ! - worker-055
#
#
# -------------------------------------------------
#
#
# There is nothing in this data.The data of 30th day has been recorded success ! - worker-089
#
# -------------------------
# ------------------------
# Total time: 147.52697348594666 seconds. - worker-004
# Crawler Finish. - worker-004
# ------------------------
# ------------------------
# -------------------------Total time: 147.55789136886597 seconds. - worker-055
# Crawler Finish. - worker-055
# There is nothing in this data.
# -------------------------
#
# ------------------------
# ------------------------
# Total time: 147.57684016227722 seconds. - worker-073
# Crawler Finish. - worker-073
# ------------------------
# The data of 31th day has been recorded success ! - worker-057
# -------------------------
# There is nothing in this data.
# -------------------------
# ------------------------
# Total time: 147.69552397727966 seconds. - worker-037
# Crawler Finish. - worker-037
# ------------------------
# -------------------------
# There is nothing in this data.
# -------------------------
# ------------------------
# Total time: 147.77032947540283 seconds. - worker-046
# Crawler Finish. - worker-046
# ------------------------
# The data of 30th day has been recorded success ! - worker-019The data of 31th day has been recorded success ! - worker-076
#
# -------------------------
# The data of 31th day has been recorded success ! - worker-016There is nothing in this data.
# -------------------------
# ------------------------
# Total time: 147.92230415344238 seconds. - worker-053
# Crawler Finish. - worker-053
# ------------------------
# The data of 31th day has been recorded success ! - worker-028
#
# The data of 30th day has been recorded success ! - worker-083------------------------
# Total time: 147.9631953239441 seconds. - worker-057
# Crawler Finish. - worker-057
# ------------------------
# -------------------------------------------------
# There is nothing in this data.
# -------------------------
# The data of 30th day has been recorded success ! - worker-119------------------------
#
# The data of 30th day has been recorded success ! - worker-036-------------------------Total time: 147.9701750278473 seconds. - worker-076
# ------------------------
# There is nothing in this data.
# -------------------------
# ------------------------
# Total time: 148.42299437522888 seconds. - worker-092
# Crawler Finish. - worker-092
# ------------------------
#
# Total time: 148.10034704208374 seconds. - worker-016
# ------------------------
# Total time: 148.45491003990173 seconds. - worker-028
# Crawler Finish. - worker-028
# ------------------------
#
# Total time: 148.45590806007385 seconds. - worker-041
# Crawler Finish. - worker-041
# ------------------------
# The data of 30th day has been recorded success ! - worker-077
# The data of 31th day has been recorded success ! - worker-114Crawler Finish. - worker-016
#
# The data of 31th day has been recorded success ! - worker-050Crawler Finish. - worker-076The data of 30th day has been recorded success ! - worker-031
#
#
#
# ------------------------
# ------------------------
#
# ------------------------
# Total time: 148.55264902114868 seconds. - worker-050
# Crawler Finish. - worker-050
# ------------------------
# ------------------------
# Total time: 148.4967963695526 seconds. - worker-114
# Crawler Finish. - worker-114
# ------------------------
# -------------------------
# There is nothing in this data.
# -------------------------
# ------------------------
# Total time: 148.6823024749756 seconds. - worker-058
# Crawler Finish. - worker-058
# ------------------------
# The data of 30th day has been recorded success ! - worker-095
# -------------------------
# There is nothing in this data.The data of 30th day has been recorded success ! - worker-022
# The data of 30th day has been recorded success ! - worker-069-------------------------
# The data of 31th day has been recorded success ! - worker-086
# ------------------------
# Total time: 148.79400396347046 seconds. - worker-013
# Crawler Finish. - worker-013
# ------------------------
#
#
# ------------------------The data of 30th day has been recorded success ! - worker-110
#
# Total time: 148.79699420928955 seconds. - worker-086
# Crawler Finish. - worker-086
# ------------------------
# The data of 31th day has been recorded success ! - worker-100The data of 31th day has been recorded success ! - worker-098
#
# ------------------------
# Total time: 148.83189463615417 seconds. - worker-098
# Crawler Finish. - worker-098
# ------------------------
# The data of 31th day has been recorded success ! - worker-090
# ------------------------
# Total time: 148.90769863128662 seconds. - worker-100
# Crawler Finish. - worker-100-------------------------
# There is nothing in this data.
# -------------------------
# ------------------------
# ------------------------
#
# ------------------------
# Total time: 148.98947930335999 seconds. - worker-097Total time: 148.95656752586365 seconds. - worker-090The data of 31th day has been recorded success ! - worker-103-------------------------
#
# -------------------------There is nothing in this data.
#
# Crawler Finish. - worker-097
#
# ------------------------
# There is nothing in this data.
# -------------------------
#
# The data of 31th day has been recorded success ! - worker-054
# Crawler Finish. - worker-090-------------------------
# -------------------------------------------------------------------------
#
# -------------------------There is nothing in this data.The data of 31th day has been recorded success ! - worker-014
# There is nothing in this data.
# -------------------------
# -------------------------
# The data of 31th day has been recorded success ! - worker-081
# ------------------------
# Total time: 149.30962300300598 seconds. - worker-081
# Crawler Finish. - worker-081
# ------------------------
# Total time: 149.2188663482666 seconds. - worker-101
# Crawler Finish. - worker-101
# ------------------------
# ------------------------
# Total time: 149.33056807518005 seconds. - worker-049
# Crawler Finish. - worker-049
# ------------------------
#
# -------------------------
#
#
# There is nothing in this data.The data of 31th day has been recorded success ! - worker-047The data of 31th day has been recorded success ! - worker-035
#
#
# ------------------------The data of 30th day has been recorded success ! - worker-111Total time: 149.26973032951355 seconds. - worker-032The data of 30th day has been recorded success ! - worker-071
# ------------------------
# Total time: 149.34177112579346 seconds. - worker-070
# Crawler Finish. - worker-070
# ------------------------
#
# Crawler Finish. - worker-032-------------------------
#
# ------------------------
# ------------------------
# ------------------------
# Total time: 149.394624710083 seconds. - worker-051
# Crawler Finish. - worker-051
# ------------------------
# Total time: 149.36869406700134 seconds. - worker-014
# ------------------------
#
#
# Crawler Finish. - worker-014
# ------------------------------------------------
# Total time: 149.41756296157837 seconds. - worker-054
#
# ------------------------
# Total time: 149.29965233802795 seconds. - worker-103
# Crawler Finish. - worker-103
# ------------------------The data of 31th day has been recorded success ! - worker-102
#
# The data of 31th day has been recorded success ! - worker-042
#
# ------------------------Crawler Finish. - worker-054
# ------------------------Total time: 149.46871733665466 seconds. - worker-047
#
# Total time: 149.42354726791382 seconds. - worker-035------------------------
# Crawler Finish. - worker-047
# ------------------------
# ------------------------
#
#
# Total time: 149.48467445373535 seconds. - worker-042Crawler Finish. - worker-035
# Total time: 149.47170901298523 seconds. - worker-102
# Crawler Finish. - worker-042
# ------------------------
# -------------------------------------------------
# There is nothing in this data.
# -------------------------
# The data of 31th day has been recorded success ! - worker-091
# -------------------------
# There is nothing in this data.
# -------------------------
# ------------------------
# Crawler Finish. - worker-102Total time: 149.5809280872345 seconds. - worker-085------------------------
#
# Total time: 149.55599570274353 seconds. - worker-116
# Crawler Finish. - worker-085
# ------------------------
# ------------------------------------------------
# Total time: 149.64427089691162 seconds. - worker-091
# The data of 30th day has been recorded success ! - worker-087
# Crawler Finish. - worker-091
#
# Crawler Finish. - worker-116
# ------------------------
# The data of 29th day has been recorded success ! - worker-009The data of 31th day has been recorded success ! - worker-107The data of 31th day has been recorded success ! - worker-105------------------------
#
#
# -------------------------
#
#
# There is nothing in this data.
# -------------------------
# The data of 31th day has been recorded success ! - worker-096-------------------------
# ------------------------
# Total time: 149.92778635025024 seconds. - worker-118
# Crawler Finish. - worker-118
# ------------------------
# -------------------------------------------------
# There is nothing in this data.
#
#
# The data of 31th day has been recorded success ! - worker-088------------------------There is nothing in this data.-------------------------
# Total time: 150.08835697174072 seconds. - worker-009
# ------------------------
#
# The data of 31th day has been recorded success ! - worker-078
# Crawler Finish. - worker-009
# Total time: 150.0375018119812 seconds. - worker-105
#
# -------------------------
# Total time: 150.14221239089966 seconds. - worker-020------------------------
#
# ------------------------
#
# Crawler Finish. - worker-020
# ------------------------
# The data of 31th day has been recorded success ! - worker-043Total time: 150.12126779556274 seconds. - worker-107
# Crawler Finish. - worker-107
# ------------------------
#
# Crawler Finish. - worker-105------------------------
# ------------------------
#
# Total time: 150.18109822273254 seconds. - worker-068-------------------------
# Crawler Finish. - worker-068
# ------------------------There is nothing in this data.
# -------------------------
# ------------------------
# Total time: 150.21302342414856 seconds. - worker-015
# Crawler Finish. - worker-015
# ------------------------
#
# -------------------------------------------------
# There is nothing in this data.
# -------------------------
# ------------------------
# Total time: 150.18908596038818 seconds. - worker-089
# Crawler Finish. - worker-089
# ------------------------
#
# ------------------------
# The data of 30th day has been recorded success ! - worker-094------------------------
# ------------------------
# Total time: 150.249924659729 seconds. - worker-043
# Crawler Finish. - worker-043
# ------------------------Total time: 150.2130184173584 seconds. - worker-078Total time: 150.18011093139648 seconds. - worker-088
#
#
# Crawler Finish. - worker-078
# ------------------------
# The data of 31th day has been recorded success ! - worker-033-------------------------
# There is nothing in this data.
# -------------------------
#
# Crawler Finish. - worker-088
#
#
# The data of 31th day has been recorded success ! - worker-019
# ------------------------
# Total time: 150.39156031608582 seconds. - worker-029
# Crawler Finish. - worker-029
# ------------------------
# Total time: 150.21003103256226 seconds. - worker-096
# Crawler Finish. - worker-096
# ------------------------
# -------------------------
# There is nothing in this data.
# -------------------------
# ------------------------------------------------
# ------------------------Total time: 150.4164798259735 seconds. - worker-033
#
# Total time: 150.3785800933838 seconds. - worker-106
# Crawler Finish. - worker-106
# ------------------------
#
# Crawler Finish. - worker-033
# ------------------------
# The data of 31th day has been recorded success ! - worker-071
# The data of 31th day has been recorded success ! - worker-108The data of 31th day has been recorded success ! - worker-095-------------------------
#
# There is nothing in this data.
# -------------------------
# The data of 31th day has been recorded success ! - worker-031
# ------------------------
# Total time: 150.6348898410797 seconds. - worker-077
# Crawler Finish. - worker-077
# ------------------------
# -------------------------The data of 31th day has been recorded success ! - worker-036
#
#
# There is nothing in this data.------------------------
# -------------------------
# ------------------------
# Total time: 150.6528468132019 seconds. - worker-071
# Crawler Finish. - worker-071
# ------------------------
# ------------------------The data of 31th day has been recorded success ! - worker-083
#
#
# Total time: 150.66581296920776 seconds. - worker-036
# Crawler Finish. - worker-036
# ------------------------
# ------------------------------------------------------------------------Total time: 150.6688039302826 seconds. - worker-019------------------------
#
#
# Total time: 150.69274020195007 seconds. - worker-022The data of 31th day has been recorded success ! - worker-110Total time: 150.65982913970947 seconds. - worker-095
# The data of 31th day has been recorded success ! - worker-119
#
# Crawler Finish. - worker-019
# ------------------------Total time: 150.70371055603027 seconds. - worker-031
#
# Total time: 150.64486956596375 seconds. - worker-108
# Crawler Finish. - worker-108
# ------------------------
# Crawler Finish. - worker-095
# ------------------------
# Crawler Finish. - worker-022
# ------------------------
# ------------------------
# Total time: 150.54413652420044 seconds. - worker-119
# Crawler Finish. - worker-119
# ------------------------
#
#
# Total time: 150.69871473312378 seconds. - worker-083
# Crawler Finish. - worker-083
# ------------------------
# ------------------------
#
# Crawler Finish. - worker-031
# ------------------------
# ------------------------
# Total time: 150.66880226135254 seconds. - worker-110
# Crawler Finish. - worker-110
# ------------------------
# -------------------------
# There is nothing in this data.
# -------------------------
# ------------------------
# Total time: 150.68476104736328 seconds. - worker-111
# Crawler Finish. - worker-111
# ------------------------
# The data of 31th day has been recorded success ! - worker-069
# ------------------------
# Total time: 150.75755763053894 seconds. - worker-069
# Crawler Finish. - worker-069
# ------------------------
# -------------------------
# There is nothing in this data.
# -------------------------
# ------------------------
# Total time: 150.82438802719116 seconds. - worker-087
# Crawler Finish. - worker-087
# ------------------------
# -------------------------
# There is nothing in this data.
# -------------------------
# ------------------------
# Total time: 150.83236694335938 seconds. - worker-094
# Crawler Finish. - worker-094
# ------------------------
# The data of 30th day has been recorded success ! - worker-104
# -------------------------
# There is nothing in this data.
# -------------------------
# ------------------------
# Total time: 151.07805848121643 seconds. - worker-104
# Crawler Finish. - worker-104
# ------------------------

# %%
multi_df = pd.DataFrame(pd.read_csv(path+'2016/weather-2-month.csv'))
multi_df
# Out:
#            Date   Time                     Weather Temperature     Wind  \
# 0    2016/02/01  00:53          Light rain. Clear.        8 °C  28 km/h
# 1    2016/02/01  01:53                      Clear.        8 °C  20 km/h
# 2    2016/02/01  02:53                      Clear.        7 °C  17 km/h
# 3    2016/02/01  03:53                      Clear.        7 °C  22 km/h
# 4    2016/02/01  04:53                      Clear.        7 °C  24 km/h
# 5    2016/02/01  05:53                      Clear.        6 °C  17 km/h
# 6    2016/02/01  06:53                      Clear.        7 °C  19 km/h
# 7    2016/02/01  07:53                      Sunny.        7 °C  15 km/h
# 8    2016/02/01  08:53             Passing clouds.        8 °C  22 km/h
# 9    2016/02/01  09:53           Scattered clouds.        9 °C  30 km/h
# 10   2016/02/01  10:53             Passing clouds.       11 °C  30 km/h
# 11   2016/02/01  11:53             Passing clouds.       12 °C  20 km/h
# 12   2016/02/01  12:53             Passing clouds.       12 °C  26 km/h
# 13   2016/02/01  13:53           Scattered clouds.       13 °C  19 km/h
# 14   2016/02/01  14:53             Passing clouds.       13 °C  19 km/h
# 15   2016/02/01  15:53           Scattered clouds.       13 °C  19 km/h
# 16   2016/02/01  16:53           Scattered clouds.       12 °C  19 km/h
# 17   2016/02/01  17:53             Passing clouds.       10 °C  15 km/h
# 18   2016/02/01  18:53                      Clear.       10 °C  15 km/h
# 19   2016/02/01  19:53                      Clear.        9 °C  11 km/h
# 20   2016/02/01  20:53                      Clear.        9 °C  No wind
# 21   2016/02/01  21:53                      Clear.        8 °C   7 km/h
# 22   2016/02/01  22:53             Passing clouds.        7 °C  No wind
# 23   2016/02/01  23:53             Passing clouds.        4 °C   9 km/h
# 24   2016/02/02  00:53             Passing clouds.        4 °C  11 km/h
# 25   2016/02/02  01:53                      Clear.        4 °C   6 km/h
# 26   2016/02/02  02:53              Mostly cloudy.        6 °C   7 km/h
# 27   2016/02/02  03:53              Mostly cloudy.        6 °C  11 km/h
# 28   2016/02/02  04:53              Mostly cloudy.        7 °C   7 km/h
# 29   2016/02/02  05:53  Light rain. Mostly cloudy.        7 °C  13 km/h
# ..          ...    ...                         ...         ...      ...
# 665  2016/02/28  18:53             Passing clouds.       16 °C   7 km/h
# 666  2016/02/28  19:53             Passing clouds.       15 °C   9 km/h
# 667  2016/02/28  20:53              Partly cloudy.       14 °C   6 km/h
# 668  2016/02/28  21:53             Passing clouds.       13 °C  No wind
# 669  2016/02/28  22:53             Passing clouds.       14 °C  No wind
# 670  2016/02/28  23:53                 Low clouds.       13 °C   7 km/h
# 671  2016/02/29  00:53                        Fog.       14 °C   6 km/h
# 672  2016/02/29  01:53                        Fog.       13 °C   7 km/h
# 673  2016/02/29  02:53                        Fog.       13 °C  No wind
# 674  2016/02/29  03:53                        Fog.       12 °C   6 km/h
# 675  2016/02/29  04:53                        Fog.       12 °C   6 km/h
# 676  2016/02/29  05:53                        Fog.       12 °C  No wind
# 677  2016/02/29  06:53                        Fog.       12 °C  No wind
# 678  2016/02/29  07:53                        Fog.       12 °C   7 km/h
# 679  2016/02/29  08:53                        Fog.       13 °C  No wind
# 680  2016/02/29  09:53                        Fog.       13 °C  No wind
# 681  2016/02/29  10:53             Passing clouds.       16 °C  No wind
# 682  2016/02/29  11:53             Passing clouds.       19 °C  No wind
# 683  2016/02/29  12:53             Passing clouds.       22 °C   6 km/h
# 684  2016/02/29  13:53           Scattered clouds.       23 °C  11 km/h
# 685  2016/02/29  14:53              Broken clouds.       23 °C   7 km/h
# 686  2016/02/29  15:53           Scattered clouds.       24 °C   7 km/h
# 687  2016/02/29  16:53              Broken clouds.       22 °C  11 km/h
# 688  2016/02/29  17:53              Broken clouds.       21 °C   6 km/h
# 689  2016/02/29  18:53              Partly cloudy.       18 °C  11 km/h
# 690  2016/02/29  19:53              Partly cloudy.       19 °C   6 km/h
# 691  2016/02/29  20:53              Partly cloudy.       18 °C  No wind
# 692  2016/02/29  21:53             Passing clouds.       17 °C   6 km/h
# 693  2016/02/29  22:53             Passing clouds.       16 °C  No wind
# 694  2016/02/29  23:53             Passing clouds.       15 °C   6 km/h
#
#      Barometer                                     Wind Direction Humidity  \
# 0    1016 mbar      Wind blowing from 310° Northwest to Southeast      56%
# 1    1017 mbar      Wind blowing from 320° Northwest to Southeast      58%
# 2    1016 mbar      Wind blowing from 310° Northwest to Southeast      56%
# 3    1017 mbar  Wind blowing from 300° West-northwest to East-...      60%
# 4    1018 mbar  Wind blowing from 300° West-northwest to East-...      60%
# 5    1019 mbar      Wind blowing from 310° Northwest to Southeast      62%
# 6    1020 mbar      Wind blowing from 310° Northwest to Southeast      58%
# 7    1021 mbar      Wind blowing from 310° Northwest to Southeast      58%
# 8    1022 mbar      Wind blowing from 320° Northwest to Southeast      54%
# 9    1023 mbar  Wind blowing from 300° West-northwest to East-...      52%
# 10   1023 mbar                Wind blowing from 280° West to East      45%
# 11   1023 mbar                Wind blowing from 280° West to East      47%
# 12   1022 mbar                Wind blowing from 280° West to East      41%
# 13   1022 mbar  Wind blowing from 300° West-northwest to East-...      40%
# 14   1023 mbar  Wind blowing from 290° West-northwest to East-...      37%
# 15   1023 mbar  Wind blowing from 300° West-northwest to East-...      39%
# 16   1023 mbar  Wind blowing from 300° West-northwest to East-...      47%
# 17   1024 mbar  Wind blowing from 290° West-northwest to East-...      54%
# 18   1024 mbar                Wind blowing from 270° West to East      61%
# 19   1025 mbar  Wind blowing from 290° West-northwest to East-...      66%
# 20   1025 mbar                Wind blowing from 0° North to South      64%
# 21   1025 mbar  Wind blowing from 120° East-southeast to West-...      63%
# 22   1025 mbar                Wind blowing from 0° North to South      68%
# 23   1026 mbar  Wind blowing from 120° East-southeast to West-...      77%
# 24   1025 mbar  Wind blowing from 110° East-southeast to West-...      79%
# 25   1025 mbar  Wind blowing from 150° South-southeast to Nort...      80%
# 26   1025 mbar                Wind blowing from 100° East to West      76%
# 27   1024 mbar  Wind blowing from 120° East-southeast to West-...      76%
# 28   1024 mbar  Wind blowing from 110° East-southeast to West-...      76%
# 29   1024 mbar      Wind blowing from 130° Southeast to Northwest      82%
# ..         ...                                                ...      ...
# 665  1022 mbar              Wind blowing from 350° North to South      72%
# 666  1022 mbar  Wind blowing from 330° North-northwest to Sout...      81%
# 667  1022 mbar      Wind blowing from 310° Northwest to Southeast      87%
# 668  1023 mbar                Wind blowing from 0° North to South      90%
# 669  1023 mbar                Wind blowing from 0° North to South      90%
# 670  1022 mbar              Wind blowing from 180° South to North      90%
# 671  1022 mbar  Wind blowing from 340° North-northwest to Sout...      90%
# 672  1022 mbar  Wind blowing from 110° East-southeast to West-...      90%
# 673  1021 mbar                Wind blowing from 0° North to South      93%
# 674  1021 mbar                 Wind blowing from 90° East to West      97%
# 675  1022 mbar       Wind blowing from 50° Northeast to Southwest      97%
# 676  1021 mbar                Wind blowing from 0° North to South      97%
# 677  1022 mbar                Wind blowing from 0° North to South      93%
# 678  1022 mbar      Wind blowing from 140° Southeast to Northwest      93%
# 679  1023 mbar                Wind blowing from 0° North to South      90%
# 680  1023 mbar                Wind blowing from 0° North to South      87%
# 681  1022 mbar                Wind blowing from 0° North to South      78%
# 682  1022 mbar                Wind blowing from 0° North to South      57%
# 683  1021 mbar  Wind blowing from 330° North-northwest to Sout...      51%
# 684  1020 mbar  Wind blowing from 300° West-northwest to East-...      46%
# 685  1020 mbar                Wind blowing from 270° West to East      46%
# 686  1019 mbar      Wind blowing from 320° Northwest to Southeast      42%
# 687  1019 mbar      Wind blowing from 310° Northwest to Southeast      46%
# 688  1019 mbar      Wind blowing from 320° Northwest to Southeast      51%
# 689  1020 mbar                Wind blowing from 280° West to East      63%
# 690  1020 mbar  Wind blowing from 30° North-northeast to South...      55%
# 691  1020 mbar                Wind blowing from 0° North to South      61%
# 692  1020 mbar      Wind blowing from 130° Southeast to Northwest      60%
# 693  1020 mbar                Wind blowing from 0° North to South      58%
# 694  1020 mbar      Wind blowing from 140° Southeast to Northwest      62%
#
#     Visibility
# 0        16 km
# 1        16 km
# 2        16 km
# 3        16 km
# 4        16 km
# 5        16 km
# 6        16 km
# 7        16 km
# 8        16 km
# 9        16 km
# 10       16 km
# 11       16 km
# 12       16 km
# 13       16 km
# 14       16 km
# 15       16 km
# 16       16 km
# 17       16 km
# 18       16 km
# 19       16 km
# 20       16 km
# 21       16 km
# 22       16 km
# 23       16 km
# 24       16 km
# 25       16 km
# 26       16 km
# 27       16 km
# 28       16 km
# 29       16 km
# ..         ...
# 665      16 km
# 666      16 km
# 667      16 km
# 668      16 km
# 669      14 km
# 670      14 km
# 671       8 km
# 672      10 km
# 673       6 km
# 674       2 km
# 675       2 km
# 676       2 km
# 677       2 km
# 678       3 km
# 679       4 km
# 680       5 km
# 681      16 km
# 682      16 km
# 683      16 km
# 684      16 km
# 685      16 km
# 686      16 km
# 687      16 km
# 688      16 km
# 689      16 km
# 690      16 km
# 691      16 km
# 692      16 km
# 693      16 km
# 694      16 km
#
# [695 rows x 9 columns]
